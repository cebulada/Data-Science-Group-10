# %% [markdown]
# # Jupyter Notebook Purpose
# - Run all code cells and you will have the data processed into 1 .csv or 1 .csv.gz file
#     - the geopandas part can be skipped if you are unable to `pip install` or `conda install`

# %%
# Group 10 Collaborators
COLLABORATORS = ["Nidhi Punja",
                 "Judith Roth",
                 "Iman Dordizadeh Basirabad",
                 "Daniel Adam Cebula",
                 "Cynthia Fung",
                 "Ben Klassen"]

# Group 10 Members
for _ in COLLABORATORS:
    print(f"Group 10 Member: {_:->30}")
# Out:
# Group 10 Member: -------------------Nidhi Punja
# Group 10 Member: -------------------Judith Roth
# Group 10 Member: -----Iman Dordizadeh Basirabad
# Group 10 Member: ------------Daniel Adam Cebula
# Group 10 Member: ------------------Cynthia Fung
# Group 10 Member: -------------------Ben Klassen

# %% [markdown]
# # Table of Contents
#
# ## 1. [Python Dependencies](#1)
# ### a. [Geopandas Issue](#1a)
# ___
# ## 2. [Folder Creation](#2)
# - repeated just in case
# ___
# ## 3. [Toronto Fire Services Station Locations](#3)
# ### a. [From Shapefile to .csv](#3a)
# ___
# ## 4. [Toronto Fire Incidents merged with Toronto Weather](#4) - MOVED TO 03-DONE.ipynb
# ### a. [Merge DataFrames](#4a) - MOVED TO 03-DONE.ipynb
# ___
# ## 5. [Haversine Formula](#5)
# ### a. [Python Formula](#5a)
# ### b. [Closest Toronto Fire Services Station](#5b)
# ### c. [Closest Toronto Fire Hydrant](#5c)
# - ABANDONED DUE TO LACK OF COMPUTER RESOURCES
# ___
# ## 6. [Manipulations of Fire Incidents Dataset](#6)
# ### a. [Create Minutes to Arrival and Minutes to Leave Columns](#6a)
# ### b. [Rename and Drop Columns and Change Datatypes](#6b)
# ___
# ## 7. [Creation of Zipped CSV Files](#7)

# %% [markdown]
# # 1
# # Python Dependencies

# %%
# Python Modules for Miscellaneous reasons
from zipfile import ZipFile  # to read and write to zipped folders
import requests  # simple HTTP library for Python
import os        # portable way to use operating system functionalities
import io        # Tool for working with streams (Input/Ouput data)
import datetime  # python classes for manipulating dates and times
import dateutil  # powerful extensions to standard datetime Python module
import time      # used for time.sleep() to delay the HTTP requests ever so slightly
import re        # used for Python regex library
import math      # radians, cos, sin, asin and sqrt are used for haversine formula
from IPython.display import display # use this to see the entire DataFrame in the right format
from create_folder import create_folder # create folder function that I have defined and placed in create_folder.py file

# %%
# DATA ANALYSIS Python Dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# # 1a
# # Geopandas Issue
# ## Geopandas has conflicts with a matplotlib library dependency
# - Will need to create another Conda Virtual Environment to use it
#     - Well you do not, as I have included the .csv file so you do not need to do the following steps to generate it
#     - I have commented out all code cells that would cause issues
#     - If you wish I have left instructions on how to do so

# %% [markdown]
# ## Create a geopandas Conda Virtual Environment
#
# ### 1. Create another Conda Virtual Environment - [link](https://geopandas.org/install.html)
#
# #### A. ```conda create -n geo_env```
#     - press 'y' and ENTER
# #### B. ```conda activate geo_env```
#     - MAKE SURE YOU ARE IN THE ```geo_env``` for all the following steps
# #### C. ```conda config --env --add channels conda-forge```
# #### D. ```conda config --env --set channel_priority strict```
# #### E. ```conda install python=3 geopandas```
#
# ### 2. Download Jupyter Lab / Notebook - [link](https://jupyterlab.readthedocs.io/en/stable/getting_started/installation.html)
#
# #### A. ```conda install -c conda-forge jupyterlab```
#
# ### 3. Open up this notebook in Jupyter Notebook / Lab
# - ```jupyter lab```
# - ```jupyter notebook```

# %%
# import geopandas as gpd

# %% [markdown]
# # 2
# # Creation of Folders
# - these folders will be used to store `RAW_ZIPPED/`, `RAW_UNZIPPED/`, `PROCESSED_ZIPPED/`, `PROCESSED_UNZIPPED/` data files
# - it is assumed that you do not have them so I will create them for you if you do not have them

# %%
# Here are the major directory names that will hold the data / metadata
RAW_ZIPPED_DIRECTORY = create_folder(folder_name="RAW_ZIPPED")
RAW_UNZIPPED_DIRECTORY = create_folder(folder_name="RAW_UNZIPPED")
PROCESSED_ZIPPED_DIRECTORY = create_folder(folder_name="PROCESSED_ZIPPED")
PROCESSED_UNZIPPED_DIRECTORY = create_folder(folder_name="PROCESSED_UNZIPPED")

# %%
# Create folders for fire_incidents
FIRE_RAW_ZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(RAW_ZIPPED_DIRECTORY, "FIRE_INCIDENTS"))
FIRE_RAW_UNZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(RAW_UNZIPPED_DIRECTORY, "FIRE_INCIDENTS"))
FIRE_PROCESSED_ZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(PROCESSED_ZIPPED_DIRECTORY, "FIRE_INCIDENTS"))
FIRE_PROCESSED_UNZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(PROCESSED_UNZIPPED_DIRECTORY, "FIRE_INCIDENTS"))

# %%
# Create folders for toronto_weather
WEATHER_RAW_UNZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(RAW_UNZIPPED_DIRECTORY, "TORONTO_WEATHER"))
WEATHER_PROCESSED_UNZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(PROCESSED_UNZIPPED_DIRECTORY, "TORONTO_WEATHER"))
WEATHER_PROCESSED_ZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(PROCESSED_ZIPPED_DIRECTORY, "TORONTO_WEATHER"))
WEATHER_PROCESSED_UNZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(PROCESSED_UNZIPPED_DIRECTORY, "TORONTO_WEATHER"))

# %%
# Create folders for fire_stations
STATIONS_RAW_ZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(RAW_ZIPPED_DIRECTORY, "FIRE_STATIONS"))
STATIONS_RAW_UNZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(RAW_UNZIPPED_DIRECTORY, "FIRE_STATIONS"))
STATIONS_PROCESSED_ZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(PROCESSED_ZIPPED_DIRECTORY, "FIRE_STATIONS"))
STATIONS_PROCESSED_UNZIPPED_DIRECTORY = create_folder(folder_name=os.path.join(PROCESSED_UNZIPPED_DIRECTORY, "FIRE_STATIONS"))

# %% [markdown]
# # 3
# # Toronto Fire Services Station Locations

# %% [markdown]
# # 3a
# # From Shapefile to .csv

# %%
# # get the shapefile path
# SHAPEFILE_PATH = os.path.join(STATIONS_RAW_UNZIPPED_DIRECTORY, "FIRE_FACILITY_WGS84.shp")

# # allow Geopandas to read it
# shapefile = gpd.read_file(SHAPEFILE_PATH)
# shapefile
# Out:
#                 NAME              ADDRESS           X            Y   LATITUDE  \
# 0   FIRE STATION 214    745 MEADOWVALE RD  331855.873  4850304.607  43.794219
# 1   FIRE STATION 215  5318 LAWRENCE AVE E  333114.022  4848441.177  43.777401
# 2   FIRE STATION 221  2575 EGLINTON AVE E  324515.001  4843677.541  43.734799
# 3   FIRE STATION 222       755 WARDEN AVE  322180.852  4842072.337  43.720408
# 4   FIRE STATION 223        116 DORSET RD  326275.035  4842479.439  43.723965
# ..               ...                  ...         ...          ...        ...
# 79  FIRE STATION 145        20 BEFFORT RD  308003.882  4843645.466  43.734764
# 80  FIRE STATION 146         2220 JANE ST  303996.599  4842402.430  43.723581
# 81  FIRE STATION 211      900 TAPSCOTT RD  325466.636  4853590.517  43.824001
# 82  FIRE STATION 212  8500 SHEPPARD AVE E  329838.107  4851487.882  43.804941
# 83  FIRE STATION 213         7 LAPSLEY RD  326837.049  4850419.039  43.795415
#
#     LONGITUDE                     WARD_NAME     MUN_NAME   OBJECTID  \
# 0  -79.163605         Scarborough East (44)  Scarborough  1567567.0
# 1  -79.148069         Scarborough East (44)  Scarborough  2250005.0
# 2  -79.255066    Scarborough Southwest (35)  Scarborough  2048861.0
# 3  -79.284094    Scarborough Southwest (35)  Scarborough  2449586.0
# 4  -79.233264    Scarborough Southwest (36)  Scarborough  2172861.0
# ..        ...                           ...          ...        ...
# 79 -79.460035               York Centre (9)   North York  3186765.0
# 80 -79.509779                 York West (7)   North York  3072600.0
# 81 -79.242873  Scarborough-Rouge River (42)  Scarborough  1520443.0
# 82 -79.188623  Scarborough-Rouge River (42)  Scarborough  2303629.0
# 83 -79.225965  Scarborough-Rouge River (42)  Scarborough  2458686.0
#
#                       geometry
# 0   POINT (-79.16360 43.79422)
# 1   POINT (-79.14807 43.77740)
# 2   POINT (-79.25507 43.73480)
# 3   POINT (-79.28409 43.72041)
# 4   POINT (-79.23326 43.72397)
# ..                         ...
# 79  POINT (-79.46004 43.73476)
# 80  POINT (-79.50978 43.72358)
# 81  POINT (-79.24287 43.82400)
# 82  POINT (-79.18862 43.80494)
# 83  POINT (-79.22597 43.79542)
#
# [84 rows x 10 columns]

# %%
# # convert from geopandas to pandas dataframe
# df_locations = pd.DataFrame(shapefile)

# # Set the index as the Fire Station Number
# df_locations.index = df_locations["NAME"].str.extract('(\d+)')[0].astype('int32')
# df_locations.index.name = "INDEX"
# df_locations
# Out:
#                    NAME              ADDRESS           X            Y  \
# INDEX
# 214    FIRE STATION 214    745 MEADOWVALE RD  331855.873  4850304.607
# 215    FIRE STATION 215  5318 LAWRENCE AVE E  333114.022  4848441.177
# 221    FIRE STATION 221  2575 EGLINTON AVE E  324515.001  4843677.541
# 222    FIRE STATION 222       755 WARDEN AVE  322180.852  4842072.337
# 223    FIRE STATION 223        116 DORSET RD  326275.035  4842479.439
# ...                 ...                  ...         ...          ...
# 145    FIRE STATION 145        20 BEFFORT RD  308003.882  4843645.466
# 146    FIRE STATION 146         2220 JANE ST  303996.599  4842402.430
# 211    FIRE STATION 211      900 TAPSCOTT RD  325466.636  4853590.517
# 212    FIRE STATION 212  8500 SHEPPARD AVE E  329838.107  4851487.882
# 213    FIRE STATION 213         7 LAPSLEY RD  326837.049  4850419.039
#
#         LATITUDE  LONGITUDE                     WARD_NAME     MUN_NAME  \
# INDEX
# 214    43.794219 -79.163605         Scarborough East (44)  Scarborough
# 215    43.777401 -79.148069         Scarborough East (44)  Scarborough
# 221    43.734799 -79.255066    Scarborough Southwest (35)  Scarborough
# 222    43.720408 -79.284094    Scarborough Southwest (35)  Scarborough
# 223    43.723965 -79.233264    Scarborough Southwest (36)  Scarborough
# ...          ...        ...                           ...          ...
# 145    43.734764 -79.460035               York Centre (9)   North York
# 146    43.723581 -79.509779                 York West (7)   North York
# 211    43.824001 -79.242873  Scarborough-Rouge River (42)  Scarborough
# 212    43.804941 -79.188623  Scarborough-Rouge River (42)  Scarborough
# 213    43.795415 -79.225965  Scarborough-Rouge River (42)  Scarborough
#
#         OBJECTID                    geometry
# INDEX
# 214    1567567.0  POINT (-79.16360 43.79422)
# 215    2250005.0  POINT (-79.14807 43.77740)
# 221    2048861.0  POINT (-79.25507 43.73480)
# 222    2449586.0  POINT (-79.28409 43.72041)
# 223    2172861.0  POINT (-79.23326 43.72397)
# ...          ...                         ...
# 145    3186765.0  POINT (-79.46004 43.73476)
# 146    3072600.0  POINT (-79.50978 43.72358)
# 211    1520443.0  POINT (-79.24287 43.82400)
# 212    2303629.0  POINT (-79.18862 43.80494)
# 213    2458686.0  POINT (-79.22597 43.79542)
#
# [84 rows x 10 columns]

# %%
# # get the CSV path
# SHAPEFILE_CSV_PATH = os.path.join(STATIONS_RAW_UNZIPPED_DIRECTORY,
#                                   "Toronto_Fire_Station_Locations.csv")

# # write the DataFrame to csv
# df_locations.to_csv(SHAPEFILE_CSV_PATH)

# %%
# # Do not need all the columns
# # slice out the ones that are irrelevant
# df_locations = df_locations.loc[:,
#                                ["NAME", "ADDRESS", "LATITUDE",
#                                 "LONGITUDE", "WARD_NAME", "MUN_NAME"]]
# df_locations.head()
# Out:
#                    NAME              ADDRESS   LATITUDE  LONGITUDE  \
# INDEX
# 214    FIRE STATION 214    745 MEADOWVALE RD  43.794219 -79.163605
# 215    FIRE STATION 215  5318 LAWRENCE AVE E  43.777401 -79.148069
# 221    FIRE STATION 221  2575 EGLINTON AVE E  43.734799 -79.255066
# 222    FIRE STATION 222       755 WARDEN AVE  43.720408 -79.284094
# 223    FIRE STATION 223        116 DORSET RD  43.723965 -79.233264
#
#                         WARD_NAME     MUN_NAME
# INDEX
# 214         Scarborough East (44)  Scarborough
# 215         Scarborough East (44)  Scarborough
# 221    Scarborough Southwest (35)  Scarborough
# 222    Scarborough Southwest (35)  Scarborough
# 223    Scarborough Southwest (36)  Scarborough

# %%
# # get the CSV path
# SHAPEFILE_CSV_PROCESSED_PATH = os.path.join(STATIONS_PROCESSED_UNZIPPED_DIRECTORY,
#                                   "Toronto_Fire_Station_Locations_PROCESSED.csv")

# # write the DataFrame to csv
# df_locations.to_csv(SHAPEFILE_CSV_PROCESSED_PATH)

# %% [markdown]
# ## Read in the csv
# - dont worry if you cannot do the geopandas part
# - just use the "Toronto_Fire_Station_Locations.csv" I left for you

# %%
# read in the .csv, set the index and set the lat_long column as a tuple
df_locations = pd.read_csv(
    os.path.join(STATIONS_PROCESSED_UNZIPPED_DIRECTORY,
                 "Toronto_Fire_Station_Locations_PROCESSED.csv"),
                    index_col="INDEX")
df_locations
# Out:
#                    NAME              ADDRESS   LATITUDE  LONGITUDE  \
# INDEX
# 214    FIRE STATION 214    745 MEADOWVALE RD  43.794219 -79.163605
# 215    FIRE STATION 215  5318 LAWRENCE AVE E  43.777401 -79.148069
# 221    FIRE STATION 221  2575 EGLINTON AVE E  43.734799 -79.255066
# 222    FIRE STATION 222       755 WARDEN AVE  43.720408 -79.284094
# 223    FIRE STATION 223        116 DORSET RD  43.723965 -79.233264
# ...                 ...                  ...        ...        ...
# 145    FIRE STATION 145        20 BEFFORT RD  43.734764 -79.460035
# 146    FIRE STATION 146         2220 JANE ST  43.723581 -79.509779
# 211    FIRE STATION 211      900 TAPSCOTT RD  43.824001 -79.242873
# 212    FIRE STATION 212  8500 SHEPPARD AVE E  43.804941 -79.188623
# 213    FIRE STATION 213         7 LAPSLEY RD  43.795415 -79.225965
#
#                           WARD_NAME     MUN_NAME
# INDEX
# 214           Scarborough East (44)  Scarborough
# 215           Scarborough East (44)  Scarborough
# 221      Scarborough Southwest (35)  Scarborough
# 222      Scarborough Southwest (35)  Scarborough
# 223      Scarborough Southwest (36)  Scarborough
# ...                             ...          ...
# 145                 York Centre (9)   North York
# 146                   York West (7)   North York
# 211    Scarborough-Rouge River (42)  Scarborough
# 212    Scarborough-Rouge River (42)  Scarborough
# 213    Scarborough-Rouge River (42)  Scarborough
#
# [84 rows x 6 columns]

# %%
# data types are appropriate
df_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 214 to 213
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   NAME       84 non-null     object
#  1   ADDRESS    84 non-null     object
#  2   LATITUDE   84 non-null     float64
#  3   LONGITUDE  84 non-null     float64
#  4   WARD_NAME  84 non-null     object
#  5   MUN_NAME   84 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 4.6+ KB

# %%
# all values are not null
df_locations.isnull().sum()
# Out:
# NAME         0
# ADDRESS      0
# LATITUDE     0
# LONGITUDE    0
# WARD_NAME    0
# MUN_NAME     0
# dtype: int64

# %%
# there are no duplicates either
df_locations["NAME"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 4
# # Toronto Fire Incidents merged with Toronto Weather

# %% [markdown]
# # 4a
# # Merge DataFrames

# %%
# read in the fire incident csv as a DataFrame
FIRE_PATH = os.path.join(FIRE_PROCESSED_UNZIPPED_DIRECTORY,
                         "2011-2018_Basic_Incident_Details.csv")
df_fire = pd.read_csv(FIRE_PATH, parse_dates=["DATETIME"])

# number of rows and columns
df_fire.shape
# Out:
# (975175, 16)

# %%
# preview the DataFrame
df_fire.head()
# Out:
#   Incident Number             Initial CAD Event Type  \
# 0       F11000010                            Medical
# 1       F11000011                            Medical
# 2       F11000012                            Medical
# 3       F11000013         FIG - Fire - Grass/Rubbish
# 4       F11000014  FAHR - Alarm Highrise Residential
#
#   Initial CAD Event Call Type  \
# 0                     Medical
# 1             Carbon Monoxide
# 2                     Medical
# 3              Emergency Fire
# 4              Emergency Fire
#
#                                  Final Incident Type  Event Alarm Level  \
# 0                                 89 - Other Medical                  1
# 1                                 89 - Other Medical                  1
# 2                                 89 - Other Medical                  1
# 3  03 - NO LOSS OUTDOOR fire (exc: Sus.arson,vand...                  1
# 4               33 - Human - Malicious intent, prank                  1
#
#                              Call Source  Incident Station Area  \
# 0                    03 - From Ambulance                  342.0
# 1                               01 - 911                  131.0
# 2                    03 - From Ambulance                  324.0
# 3                               01 - 911                  345.0
# 4  05 - Telephone from Monitoring Agency                  142.0
#
#    Incident Ward   LATITUDE  Longitude                        Intersection  \
# 0              9  43.679099 -79.461761     Silverthorn Ave / Turnberry Ave
# 1             15  43.726342 -79.396401  Lawrence Ave E / Mount Pleasant Rd
# 2             14  43.668548 -79.335324              Endean Ave / Jones Ave
# 3              9  43.657123 -79.434313     Dufferin St / Dufferin Park Ave
# 4              7  43.759840 -79.516182          Driftwood Ave / Wilmont Dr
#
#         TFS Alarm Time     TFS Arrival Time Last TFS Unit Clear Time  \
# 0  2011-01-01 00:03:43  2011-01-01 00:10:02      2011-01-01 00:31:18
# 1  2011-01-01 00:03:55  2011-01-01 00:09:02      2011-01-01 00:15:13
# 2  2011-01-01 00:05:03  2011-01-01 00:09:34      2011-01-01 00:27:11
# 3  2011-01-01 00:04:46  2011-01-01 00:10:46      2011-01-01 00:20:39
# 4  2011-01-01 00:06:07  2011-01-01 00:11:03      2011-01-01 00:21:11
#
#    Persons Rescued            DATETIME
# 0              0.0 2011-01-01 00:03:43
# 1              0.0 2011-01-01 00:03:55
# 2              0.0 2011-01-01 00:05:03
# 3              0.0 2011-01-01 00:04:46
# 4              0.0 2011-01-01 00:06:07

# %%
# get datatypes of each column
df_fire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975175 entries, 0 to 975174
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Incident Number              975175 non-null  object
#  1   Initial CAD Event Type       975175 non-null  object
#  2   Initial CAD Event Call Type  975175 non-null  object
#  3   Final Incident Type          975127 non-null  object
#  4   Event Alarm Level            975175 non-null  int64
#  5   Call Source                  975105 non-null  object
#  6   Incident Station Area        975113 non-null  float64
#  7   Incident Ward                975175 non-null  int64
#  8   LATITUDE                     975127 non-null  float64
#  9   Longitude                    975127 non-null  float64
#  10  Intersection                 975126 non-null  object
#  11  TFS Alarm Time               975175 non-null  object
#  12  TFS Arrival Time             951695 non-null  object
#  13  Last TFS Unit Clear Time     975171 non-null  object
#  14  Persons Rescued              975107 non-null  float64
#  15  DATETIME                     975175 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(2), object(9)
# memory usage: 119.0+ MB

# %%
# some null values in the data but I believe they can be managed (less than <1%)
df_fire.isnull().sum()
# Out:
# Incident Number                    0
# Initial CAD Event Type             0
# Initial CAD Event Call Type        0
# Final Incident Type               48
# Event Alarm Level                  0
# Call Source                       70
# Incident Station Area             62
# Incident Ward                      0
# LATITUDE                          48
# Longitude                         48
# Intersection                      49
# TFS Alarm Time                     0
# TFS Arrival Time               23480
# Last TFS Unit Clear Time           4
# Persons Rescued                   68
# DATETIME                           0
# dtype: int64

# %%
# remove all values with null "LATITUDE" or "Longitude" through slicing
df_fire = df_fire.loc[df_fire["LATITUDE"].notnull() & df_fire["Longitude"].notnull()]
df_fire.shape
# Out:
# (975127, 16)

# %%
# 14 duplicates in Incident Number (7 rows that are replicated)
df_fire["Incident Number"].duplicated(keep=False).sum()
# Out:
# 14

# %%
# Check duplicate "Incident Number" values
# It appears that Incident Types are double booked for the same event
# This may be some sort of error
df_fire.loc[df_fire["Incident Number"].duplicated(keep=False)]
# Out:
#        Incident Number                          Initial CAD Event Type  \
# 358649       F13096124               FAHR - Alarm Highrise Residential
# 358650       F13096124               FAHR - Alarm Highrise Residential
# 359742       F13097259               CCNE - Check Call - Non Emergency
# 359743       F13097259               CCNE - Check Call - Non Emergency
# 391077       F14016411             FICI - Fire - Commercial/Industrial
# 391078       F14016411             FICI - Fire - Commercial/Industrial
# 401808       F14027496               CCNE - Check Call - Non Emergency
# 401809       F14027496               CCNE - Check Call - Non Emergency
# 459379       F14087165                                         Medical
# 459380       F14087165                                         Medical
# 534044       F15048892               VEAT - Vehicle Accident - Trapped
# 534045       F15048892               VEAT - Vehicle Accident - Trapped
# 550900       F15066701  FAHCD - Alarm Highrise - Commercial - Downtown
# 550901       F15066701  FAHCD - Alarm Highrise - Commercial - Downtown
#
#        Initial CAD Event Call Type  \
# 358649              Emergency Fire
# 358650              Emergency Fire
# 359742               Non Emergency
# 359743               Non Emergency
# 391077              Emergency Fire
# 391078              Emergency Fire
# 401808               Non Emergency
# 401809               Non Emergency
# 459379                     Medical
# 459380                     Medical
# 534044            Vehicle Incident
# 534045            Vehicle Incident
# 550900              Emergency Fire
# 550901              Emergency Fire
#
#                                       Final Incident Type  Event Alarm Level  \
# 358649                   34 - Human - Perceived Emergency                  0
# 358650                                99 - Other Response                  0
# 359742                          94 - Other Public Service                  0
# 359743                                99 - Other Response                  0
# 391077                                99 - Other Response                  0
# 391078  03 - NO LOSS OUTDOOR fire (exc: Sus.arson,vand...                  0
# 401808                          94 - Other Public Service                  0
# 401809                                99 - Other Response                  0
# 459379                                 89 - Other Medical                  0
# 459380                                 89 - Other Medical                  0
# 534044                             62 - Vehicle Collision                  0
# 534045  93 - Assistance to Other Agencies (exc 921 and...                  0
# 550900                 31 - Alarm Equipment - Malfunction                  0
# 550901  32 - Alarm System Equipment - Accidental activ...                  0
#
#                                               Call Source  \
# 358649              05 - Telephone from Monitoring Agency
# 358650              05 - Telephone from Monitoring Agency
# 359742                                   09 - Other Alarm
# 359743                                   09 - Other Alarm
# 391077                                   09 - Other Alarm
# 391078       02 - Telephone from Civlian (other than 911)
# 401808       02 - Telephone from Civlian (other than 911)
# 401809       02 - Telephone from Civlian (other than 911)
# 459379                          04 - From Police Services
# 459380  11 - No alarm received - incident discovered b...
# 534044                                03 - From Ambulance
# 534045                                03 - From Ambulance
# 550900                                           01 - 911
# 550901                                           01 - 911
#
#         Incident Station Area  Incident Ward   LATITUDE  Longitude  \
# 358649                  442.0              5  43.707785 -79.533627
# 358650                  442.0              5  43.707785 -79.533627
# 359742                  134.0             15  43.705077 -79.384773
# 359743                  134.0             15  43.705077 -79.384773
# 391077                  411.0              7  43.760025 -79.532077
# 391078                  411.0              7  43.760025 -79.532077
# 401808                  223.0             21  43.741609 -79.232610
# 401809                  223.0             21  43.741609 -79.232610
# 459379                  146.0              6  43.724894 -79.509607
# 459380                  146.0              6  43.724894 -79.509607
# 534044                  145.0              6  43.731525 -79.462878
# 534045                  145.0              6  43.731525 -79.462878
# 550900                  332.0             10  43.646055 -79.392329
# 550901                  332.0             10  43.646055 -79.392329
#
#                                         Intersection       TFS Alarm Time  \
# 358649                            Weston Rd / Oak St  2013-11-23 17:47:14
# 358650                            Weston Rd / Oak St  2013-11-23 17:47:14
# 359742                       Manor Rd E / Forman Ave  2013-11-27 13:56:18
# 359743                       Manor Rd E / Forman Ave  2013-11-27 13:56:18
# 391077                    HWY 400 / 400 S Finch Ramp  2014-02-18 14:40:34
# 391078                    HWY 400 / 400 S Finch Ramp  2014-02-18 14:40:34
# 401808  Cedar Brae Blvd / Bellamy Rd N / Trudelle St  2014-03-28 10:32:24
# 401809  Cedar Brae Blvd / Bellamy Rd N / Trudelle St  2014-03-28 10:32:24
# 459379          Jane St / Chalkfarm Dr / Heathrow Dr  2014-10-04 09:59:52
# 459380          Jane St / Chalkfarm Dr / Heathrow Dr  2014-10-04 09:59:52
# 534044                        Wilson Ave / Maniza Rd  2015-05-27 02:06:43
# 534045                        Wilson Ave / Maniza Rd  2015-05-27 02:06:43
# 550900          King St W / Peter St / Blue Jays Way  2015-07-18 16:12:34
# 550901          King St W / Peter St / Blue Jays Way  2015-07-18 16:12:34
#
#            TFS Arrival Time Last TFS Unit Clear Time  Persons Rescued  \
# 358649  2013-11-23 17:52:58      2013-11-23 19:41:10              0.0
# 358650  2013-11-23 17:52:58      2013-11-23 19:41:10              0.0
# 359742  2013-11-27 14:12:20      2013-11-28 15:06:38              0.0
# 359743  2013-11-27 14:12:20      2013-11-28 15:06:38              0.0
# 391077  2014-02-18 14:46:23      2014-02-19 08:30:41              0.0
# 391078  2014-02-18 14:46:23      2014-02-19 08:30:41              0.0
# 401808  2014-03-28 10:38:55      2014-03-28 13:44:01              0.0
# 401809  2014-03-28 10:38:55      2014-03-28 13:44:01              0.0
# 459379  2014-10-04 10:01:14      2014-10-04 14:33:26              0.0
# 459380  2014-10-04 10:01:14      2014-10-04 14:33:26              0.0
# 534044  2015-05-27 02:10:37      2015-05-27 05:56:03              0.0
# 534045  2015-05-27 02:10:37      2015-05-27 05:56:03              0.0
# 550900  2015-07-18 16:18:54      2015-07-18 18:54:11              0.0
# 550901  2015-07-18 16:18:54      2015-07-18 18:54:11              0.0
#
#                   DATETIME
# 358649 2013-11-23 17:47:14
# 358650 2013-11-23 17:47:14
# 359742 2013-11-27 13:56:18
# 359743 2013-11-27 13:56:18
# 391077 2014-02-18 14:40:34
# 391078 2014-02-18 14:40:34
# 401808 2014-03-28 10:32:24
# 401809 2014-03-28 10:32:24
# 459379 2014-10-04 09:59:52
# 459380 2014-10-04 09:59:52
# 534044 2015-05-27 02:06:43
# 534045 2015-05-27 02:06:43
# 550900 2015-07-18 16:12:34
# 550901 2015-07-18 16:12:34

# %%
# drop all values (that were duplicated) through slicing
# ~ is the Boolean NOT operator
df_fire = df_fire.loc[~df_fire["Incident Number"].duplicated(keep=False)]
df_fire.head()
# Out:
#   Incident Number             Initial CAD Event Type  \
# 0       F11000010                            Medical
# 1       F11000011                            Medical
# 2       F11000012                            Medical
# 3       F11000013         FIG - Fire - Grass/Rubbish
# 4       F11000014  FAHR - Alarm Highrise Residential
#
#   Initial CAD Event Call Type  \
# 0                     Medical
# 1             Carbon Monoxide
# 2                     Medical
# 3              Emergency Fire
# 4              Emergency Fire
#
#                                  Final Incident Type  Event Alarm Level  \
# 0                                 89 - Other Medical                  1
# 1                                 89 - Other Medical                  1
# 2                                 89 - Other Medical                  1
# 3  03 - NO LOSS OUTDOOR fire (exc: Sus.arson,vand...                  1
# 4               33 - Human - Malicious intent, prank                  1
#
#                              Call Source  Incident Station Area  \
# 0                    03 - From Ambulance                  342.0
# 1                               01 - 911                  131.0
# 2                    03 - From Ambulance                  324.0
# 3                               01 - 911                  345.0
# 4  05 - Telephone from Monitoring Agency                  142.0
#
#    Incident Ward   LATITUDE  Longitude                        Intersection  \
# 0              9  43.679099 -79.461761     Silverthorn Ave / Turnberry Ave
# 1             15  43.726342 -79.396401  Lawrence Ave E / Mount Pleasant Rd
# 2             14  43.668548 -79.335324              Endean Ave / Jones Ave
# 3              9  43.657123 -79.434313     Dufferin St / Dufferin Park Ave
# 4              7  43.759840 -79.516182          Driftwood Ave / Wilmont Dr
#
#         TFS Alarm Time     TFS Arrival Time Last TFS Unit Clear Time  \
# 0  2011-01-01 00:03:43  2011-01-01 00:10:02      2011-01-01 00:31:18
# 1  2011-01-01 00:03:55  2011-01-01 00:09:02      2011-01-01 00:15:13
# 2  2011-01-01 00:05:03  2011-01-01 00:09:34      2011-01-01 00:27:11
# 3  2011-01-01 00:04:46  2011-01-01 00:10:46      2011-01-01 00:20:39
# 4  2011-01-01 00:06:07  2011-01-01 00:11:03      2011-01-01 00:21:11
#
#    Persons Rescued            DATETIME
# 0              0.0 2011-01-01 00:03:43
# 1              0.0 2011-01-01 00:03:55
# 2              0.0 2011-01-01 00:05:03
# 3              0.0 2011-01-01 00:04:46
# 4              0.0 2011-01-01 00:06:07

# %%
# check to see if the "Incident Number" is unique for each row
len(df_fire["Incident Number"].unique()) == len(df_fire)
# Out:
# True

# %%
# set the "Incident Number" as the index, since it is unique for each row
df_fire.index = df_fire["Incident Number"]
df_fire = df_fire.drop(columns=["Incident Number"])
df_fire.index.name = "INCIDENT_NUM"
df_fire.head()
# Out:
#                          Initial CAD Event Type Initial CAD Event Call Type  \
# INCIDENT_NUM
# F11000010                               Medical                     Medical
# F11000011                               Medical             Carbon Monoxide
# F11000012                               Medical                     Medical
# F11000013            FIG - Fire - Grass/Rubbish              Emergency Fire
# F11000014     FAHR - Alarm Highrise Residential              Emergency Fire
#
#                                             Final Incident Type  \
# INCIDENT_NUM
# F11000010                                    89 - Other Medical
# F11000011                                    89 - Other Medical
# F11000012                                    89 - Other Medical
# F11000013     03 - NO LOSS OUTDOOR fire (exc: Sus.arson,vand...
# F11000014                  33 - Human - Malicious intent, prank
#
#               Event Alarm Level                            Call Source  \
# INCIDENT_NUM
# F11000010                     1                    03 - From Ambulance
# F11000011                     1                               01 - 911
# F11000012                     1                    03 - From Ambulance
# F11000013                     1                               01 - 911
# F11000014                     1  05 - Telephone from Monitoring Agency
#
#               Incident Station Area  Incident Ward   LATITUDE  Longitude  \
# INCIDENT_NUM
# F11000010                     342.0              9  43.679099 -79.461761
# F11000011                     131.0             15  43.726342 -79.396401
# F11000012                     324.0             14  43.668548 -79.335324
# F11000013                     345.0              9  43.657123 -79.434313
# F11000014                     142.0              7  43.759840 -79.516182
#
#                                     Intersection       TFS Alarm Time  \
# INCIDENT_NUM
# F11000010        Silverthorn Ave / Turnberry Ave  2011-01-01 00:03:43
# F11000011     Lawrence Ave E / Mount Pleasant Rd  2011-01-01 00:03:55
# F11000012                 Endean Ave / Jones Ave  2011-01-01 00:05:03
# F11000013        Dufferin St / Dufferin Park Ave  2011-01-01 00:04:46
# F11000014             Driftwood Ave / Wilmont Dr  2011-01-01 00:06:07
#
#                  TFS Arrival Time Last TFS Unit Clear Time  Persons Rescued  \
# INCIDENT_NUM
# F11000010     2011-01-01 00:10:02      2011-01-01 00:31:18              0.0
# F11000011     2011-01-01 00:09:02      2011-01-01 00:15:13              0.0
# F11000012     2011-01-01 00:09:34      2011-01-01 00:27:11              0.0
# F11000013     2011-01-01 00:10:46      2011-01-01 00:20:39              0.0
# F11000014     2011-01-01 00:11:03      2011-01-01 00:21:11              0.0
#
#                         DATETIME
# INCIDENT_NUM
# F11000010    2011-01-01 00:03:43
# F11000011    2011-01-01 00:03:55
# F11000012    2011-01-01 00:05:03
# F11000013    2011-01-01 00:04:46
# F11000014    2011-01-01 00:06:07

# %%
# create "lat_long" column that is a tuple of latitude and longitude
df_fire["lat_long"] = list(zip(df_fire["LATITUDE"], df_fire["Longitude"]))
df_fire.head()
# Out:
#                          Initial CAD Event Type Initial CAD Event Call Type  \
# INCIDENT_NUM
# F11000010                               Medical                     Medical
# F11000011                               Medical             Carbon Monoxide
# F11000012                               Medical                     Medical
# F11000013            FIG - Fire - Grass/Rubbish              Emergency Fire
# F11000014     FAHR - Alarm Highrise Residential              Emergency Fire
#
#                                             Final Incident Type  \
# INCIDENT_NUM
# F11000010                                    89 - Other Medical
# F11000011                                    89 - Other Medical
# F11000012                                    89 - Other Medical
# F11000013     03 - NO LOSS OUTDOOR fire (exc: Sus.arson,vand...
# F11000014                  33 - Human - Malicious intent, prank
#
#               Event Alarm Level                            Call Source  \
# INCIDENT_NUM
# F11000010                     1                    03 - From Ambulance
# F11000011                     1                               01 - 911
# F11000012                     1                    03 - From Ambulance
# F11000013                     1                               01 - 911
# F11000014                     1  05 - Telephone from Monitoring Agency
#
#               Incident Station Area  Incident Ward   LATITUDE  Longitude  \
# INCIDENT_NUM
# F11000010                     342.0              9  43.679099 -79.461761
# F11000011                     131.0             15  43.726342 -79.396401
# F11000012                     324.0             14  43.668548 -79.335324
# F11000013                     345.0              9  43.657123 -79.434313
# F11000014                     142.0              7  43.759840 -79.516182
#
#                                     Intersection       TFS Alarm Time  \
# INCIDENT_NUM
# F11000010        Silverthorn Ave / Turnberry Ave  2011-01-01 00:03:43
# F11000011     Lawrence Ave E / Mount Pleasant Rd  2011-01-01 00:03:55
# F11000012                 Endean Ave / Jones Ave  2011-01-01 00:05:03
# F11000013        Dufferin St / Dufferin Park Ave  2011-01-01 00:04:46
# F11000014             Driftwood Ave / Wilmont Dr  2011-01-01 00:06:07
#
#                  TFS Arrival Time Last TFS Unit Clear Time  Persons Rescued  \
# INCIDENT_NUM
# F11000010     2011-01-01 00:10:02      2011-01-01 00:31:18              0.0
# F11000011     2011-01-01 00:09:02      2011-01-01 00:15:13              0.0
# F11000012     2011-01-01 00:09:34      2011-01-01 00:27:11              0.0
# F11000013     2011-01-01 00:10:46      2011-01-01 00:20:39              0.0
# F11000014     2011-01-01 00:11:03      2011-01-01 00:21:11              0.0
#
#                         DATETIME                             lat_long
# INCIDENT_NUM
# F11000010    2011-01-01 00:03:43   (43.679098579, -79.46176085399999)
# F11000011    2011-01-01 00:03:55        (43.726342492, -79.396400551)
# F11000012    2011-01-01 00:05:03         (43.66854833, -79.335324059)
# F11000013    2011-01-01 00:04:46     (43.6571226, -79.43431345399999)
# F11000014    2011-01-01 00:06:07  (43.759840161999996, -79.516182424)

# %%
# write it to a folder
MERGED_FILE_PATH = os.path.join(FIRE_PROCESSED_UNZIPPED_DIRECTORY,
                               "2011-2018_Toronto_Fire_Incidents.csv")

df_fire.to_csv(MERGED_FILE_PATH)

# display 10 random values
df_fire.sample(10)
# Out:
#                               Initial CAD Event Type  \
# INCIDENT_NUM
# F17009060                                    Medical
# F12022953        FIHR - Fire -  Highrise Residential
# F18077223                                    Medical
# F12075958                    FAR - Alarm Residential
# F13005912         FACI - Alarm Commercial/Industrial
# F13044516                 FIG - Fire - Grass/Rubbish
# F12080544                                    Medical
# F13034264                            CC - Check Call
# F12120049     TEMS - TEMS TRANSFERRED - READ REMARKS
# F13017273                    FAR - Alarm Residential
#
#              Initial CAD Event Call Type  \
# INCIDENT_NUM
# F17009060                        Medical
# F12022953                 Emergency Fire
# F18077223                        Medical
# F12075958                 Emergency Fire
# F13005912                 Emergency Fire
# F13044516                 Emergency Fire
# F12080544                        Medical
# F13034264         Other Emergency Events
# F12120049                        Medical
# F13017273                 Emergency Fire
#
#                                             Final Incident Type  \
# INCIDENT_NUM
# F17009060                                    89 - Other Medical
# F12022953                  33 - Human - Malicious intent, prank
# F18077223                                    89 - Other Medical
# F12075958                    31 - Alarm Equipment - Malfunction
# F13005912     32 - Alarm System Equipment - Accidental activ...
# F13044516     23 - Open air burning/unauthorized controlled ...
# F12080544                                    89 - Other Medical
# F13034264                                   99 - Other Response
# F12120049                                62 - Vehicle Collision
# F13017273     32 - Alarm System Equipment - Accidental activ...
#
#               Event Alarm Level                                   Call Source  \
# INCIDENT_NUM
# F17009060                     0                           03 - From Ambulance
# F12022953                     0         05 - Telephone from Monitoring Agency
# F18077223                     0                           03 - From Ambulance
# F12075958                     0         05 - Telephone from Monitoring Agency
# F13005912                     0                                      01 - 911
# F13044516                     0  02 - Telephone from Civlian (other than 911)
# F12080544                     0                           03 - From Ambulance
# F13034264                     0  02 - Telephone from Civlian (other than 911)
# F12120049                     0                           03 - From Ambulance
# F13017273                     0         05 - Telephone from Monitoring Agency
#
#               Incident Station Area  Incident Ward   LATITUDE  Longitude  \
# INCIDENT_NUM
# F17009060                     313.0             14  43.676202 -79.358873
# F12022953                     224.0             19  43.695130 -79.303481
# F18077223                     114.0             18   0.000000   0.000000
# F12075958                     226.0             19  43.692588 -79.293723
# F13005912                     441.0              1  43.693790 -79.571919
# F13044516                     224.0             19  43.684309 -79.312213
# F12080544                     125.0             16  43.718360 -79.331406
# F13034264                     425.0              4  43.653412 -79.465171
# F12120049                     232.0             21  43.772142 -79.251498
# F13017273                     122.0             15  43.751671 -79.392722
#
#                                                    Intersection  \
# INCIDENT_NUM
# F17009060                          Danforth Ave / Broadview Ave
# F12022953                          Lumsden Ave / Barrington Ave
# F18077223                                                   M2N
# F12075958     Dentonia Park Ave / Sibley Ave / Dentonia Park...
# F13005912                           Martin Grove Rd / Ronson Dr
# F13044516                             Woodbine Ave / Mendel Ave
# F12080544                         Deauville Lane / St Dennis Dr
# F13034264           West Rd / Colborne Lodge Dr / High Park Trl
# F12120049                             Ellesmere Rd / McCowan Rd
# F13017273                                Fenn Ave / Danville Dr
#
#                    TFS Alarm Time     TFS Arrival Time  \
# INCIDENT_NUM
# F17009060     2017-01-28 09:48:11  2017-01-28 09:52:14
# F12022953     2012-03-01 21:46:21  2012-03-01 21:50:35
# F18077223     2018-07-21 22:14:50                  NaN
# F12075958     2012-07-17 06:46:13  2012-07-17 06:51:39
# F13005912     2013-01-21 16:21:24  2013-01-21 16:24:40
# F13044516     2013-06-08 15:41:06  2013-06-08 15:44:53
# F12080544     2012-08-01 04:17:08  2012-08-01 04:24:37
# F13034264     2013-05-05 23:35:31  2013-05-05 23:50:25
# F12120049     2012-12-14 13:49:45  2012-12-14 13:55:10
# F13017273     2013-03-02 16:13:03  2013-03-02 16:17:32
#
#              Last TFS Unit Clear Time  Persons Rescued            DATETIME  \
# INCIDENT_NUM
# F17009060         2017-01-28 09:54:12              0.0 2017-01-28 09:48:11
# F12022953         2012-03-01 22:16:07              0.0 2012-03-01 21:46:21
# F18077223         2018-07-21 22:20:29              0.0 2018-07-21 22:14:50
# F12075958         2012-07-17 07:01:51              0.0 2012-07-17 06:46:13
# F13005912         2013-01-21 16:31:36              0.0 2013-01-21 16:21:24
# F13044516         2013-06-08 15:47:54              0.0 2013-06-08 15:41:06
# F12080544         2012-08-01 04:49:47              0.0 2012-08-01 04:17:08
# F13034264         2013-05-05 23:59:38              0.0 2013-05-05 23:35:31
# F12120049         2012-12-14 14:03:05              0.0 2012-12-14 13:49:45
# F13017273         2013-03-02 16:20:10              0.0 2013-03-02 16:13:03
#
#                                          lat_long
# INCIDENT_NUM
# F17009060     (43.676202331999995, -79.358872563)
# F12022953     (43.695129656000006, -79.303480729)
# F18077223                              (0.0, 0.0)
# F12075958     (43.692587671999995, -79.293722781)
# F13005912       (43.69379026, -79.57191926899999)
# F13044516      (43.684309494, -79.31221331099998)
# F12080544     (43.718360231999995, -79.331406395)
# F13034264      (43.653412418, -79.46517054899999)
# F12120049      (43.772142024, -79.25149843199999)
# F13017273      (43.751671386000005, -79.39272233)

# %%
# read in the csv file, make sure the tuple is preserved
df_fire = pd.read_csv(
    os.path.join(FIRE_PROCESSED_UNZIPPED_DIRECTORY,
                "2011-2018_Toronto_Fire_Incidents.csv"),
                index_col="INCIDENT_NUM",
                converters={"lat_long":eval},
                parse_dates=["DATETIME"])
df_fire.head()
# Out:
#                          Initial CAD Event Type Initial CAD Event Call Type  \
# INCIDENT_NUM
# F11000010                               Medical                     Medical
# F11000011                               Medical             Carbon Monoxide
# F11000012                               Medical                     Medical
# F11000013            FIG - Fire - Grass/Rubbish              Emergency Fire
# F11000014     FAHR - Alarm Highrise Residential              Emergency Fire
#
#                                             Final Incident Type  \
# INCIDENT_NUM
# F11000010                                    89 - Other Medical
# F11000011                                    89 - Other Medical
# F11000012                                    89 - Other Medical
# F11000013     03 - NO LOSS OUTDOOR fire (exc: Sus.arson,vand...
# F11000014                  33 - Human - Malicious intent, prank
#
#               Event Alarm Level                            Call Source  \
# INCIDENT_NUM
# F11000010                     1                    03 - From Ambulance
# F11000011                     1                               01 - 911
# F11000012                     1                    03 - From Ambulance
# F11000013                     1                               01 - 911
# F11000014                     1  05 - Telephone from Monitoring Agency
#
#               Incident Station Area  Incident Ward   LATITUDE  Longitude  \
# INCIDENT_NUM
# F11000010                     342.0              9  43.679099 -79.461761
# F11000011                     131.0             15  43.726342 -79.396401
# F11000012                     324.0             14  43.668548 -79.335324
# F11000013                     345.0              9  43.657123 -79.434313
# F11000014                     142.0              7  43.759840 -79.516182
#
#                                     Intersection       TFS Alarm Time  \
# INCIDENT_NUM
# F11000010        Silverthorn Ave / Turnberry Ave  2011-01-01 00:03:43
# F11000011     Lawrence Ave E / Mount Pleasant Rd  2011-01-01 00:03:55
# F11000012                 Endean Ave / Jones Ave  2011-01-01 00:05:03
# F11000013        Dufferin St / Dufferin Park Ave  2011-01-01 00:04:46
# F11000014             Driftwood Ave / Wilmont Dr  2011-01-01 00:06:07
#
#                  TFS Arrival Time Last TFS Unit Clear Time  Persons Rescued  \
# INCIDENT_NUM
# F11000010     2011-01-01 00:10:02      2011-01-01 00:31:18              0.0
# F11000011     2011-01-01 00:09:02      2011-01-01 00:15:13              0.0
# F11000012     2011-01-01 00:09:34      2011-01-01 00:27:11              0.0
# F11000013     2011-01-01 00:10:46      2011-01-01 00:20:39              0.0
# F11000014     2011-01-01 00:11:03      2011-01-01 00:21:11              0.0
#
#                         DATETIME                             lat_long
# INCIDENT_NUM
# F11000010    2011-01-01 00:03:43   (43.679098579, -79.46176085399999)
# F11000011    2011-01-01 00:03:55        (43.726342492, -79.396400551)
# F11000012    2011-01-01 00:05:03         (43.66854833, -79.335324059)
# F11000013    2011-01-01 00:04:46     (43.6571226, -79.43431345399999)
# F11000014    2011-01-01 00:06:07  (43.759840161999996, -79.516182424)

# %% [markdown]
# # 5
# # Haversine Formula
# - Determine great-circle distance between 2 points on a sphere - [link](https://en.wikipedia.org/wiki/Haversine_formula)
# - Needed to relate the location of Toronto Fire Services Stations and Toronto Fire Hydrants to all incidents
#     - determine the closest stations and Fire Hydrants
#     - maybe there are overused Stations / Fire Hydrants that require additional resources

# %%
# Python Haversine formula
# Adapted from
# "https://stackoverflow.com/questions/4913349/haversine-formula-in-python-bearing-and-distance-between-two-gps-points"
def haversine(latit_1=-90, latit_2=90, longit_1=0, longit_2=180, radius=6371000):
    """
    determines the great-circle distance between two
    points on a sphere (default value is Earth's) given their longitudes and latitudes.
    Longitudes and Latitudes are in decimal degrees.
    Returns value in metres (m).
    """
    # convert decimal degrees to radians
    longit_1 = math.radians(longit_1)
    latit_1 = math.radians(latit_1)
    longit_2 = math.radians(longit_2)
    latit_2 = math.radians(latit_2)
    
    # calculate the difference between latitudes and longitudes
    delta_latitude = latit_1 - latit_2
    delta_longitude = longit_1 - longit_2
    
    # great circle distance
    a = math.sin(delta_latitude / 2)**2 + math.cos(latit_1) * math.cos(latit_2) * math.sin(delta_longitude / 2)**2
    c = 2 * math.asin(math.sqrt(a))
    
    # return the great circle distance for Earth
    return radius * c

# since I get pi back that means it works
haversine()/6371000
# Out:
# 3.141592653589793

# %%
# Python Haversine formula for numpy arrays
# An attempt to make the computation take less time (~1000 minutes for ~1 million rows)
# this one should take x10-x30 times less
def np_haversine(latit_1=-90, latit_2=90, longit_1=0, longit_2=180, radius=6371000):
    """
    Calculate great circle distance between 2 points on a sphere (Earth is default).
    Positions are in decimal degrees.
    Function was rewritten to be calculated unsing Numpy methods.
    Returns value in metres (m).
    """
    # convert decimal degrees to radians
    latit_1 = np.radians(latit_1)
    latit_2 = np.radians(latit_2)
    longit_1 = np.radians(longit_1)
    longit_2 = np.radians(longit_2)
    
    # calculate the difference between latitudes and longitudes
    delta_latitude = latit_1 - latit_2
    delta_longitude = longit_1 - longit_2
    
    # great circle distance
    a = np.sin(delta_latitude / 2)**2 + np.cos(latit_1) * np.cos(latit_2) * np.sin(delta_longitude / 2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    # return the distance
    return radius * c

np_haversine()/6371000
# Out:
# 3.141592653589793

# %% [markdown]
# # 5b
# # Closest Toronto Fire Services Station

# %%
# get LATITUDE and LONGITUDE of each fire department
df_station_locations = df_locations.loc[:, ["LATITUDE", "LONGITUDE"]]
df_station_locations.head()
# Out:
#         LATITUDE  LONGITUDE
# INDEX
# 214    43.794219 -79.163605
# 215    43.777401 -79.148069
# 221    43.734799 -79.255066
# 222    43.720408 -79.284094
# 223    43.723965 -79.233264

# %%
# get the minimum value and replace the value in lat_longs with the index value
# corresponding to the Closest Fire Station
def Closest_Point(x):
    """
    Get the closest point from all the datapoints in df_location
    """
    if x == np.nan:
        return x
    
    # use the above DataFrame
    global df_station_locations
    
    # broadcasting will get us all the values we need
    np_haversine_array = np.array(
                        np_haversine(
                        df_station_locations["LATITUDE"].values,
                        x[0],
                        df_station_locations["LONGITUDE"].values,
                        x[1]
                                    )
                        )
    
    # get the minimum index
    minimum_index = np.argmin(np_haversine_array)
    
    # return the index of the minimum distance
    return df_station_locations.index[minimum_index]

# %% [markdown]
# ## The following code will take about ~20 minutes to run
# - This is essentially a VLOOKUP() function from Excel
# - YOU HAVE BEEN WARNED

# %%
# apply the Closest_Point function to obtain the Fire Station closest to the Event
df_slice = df_fire.copy()
df_slice["FIRE_STATION_CLOSEST"] = df_slice["lat_long"].apply(lambda x: Closest_Point(x))
df_slice
# Out:
#                                    Initial CAD Event Type  \
# INCIDENT_NUM
# F11000010                                         Medical
# F11000011                                         Medical
# F11000012                                         Medical
# F11000013                      FIG - Fire - Grass/Rubbish
# F11000014               FAHR - Alarm Highrise Residential
# ...                                                   ...
# F18139238     FAHRD - Alarm Highrise Residential Downtown
# F18139239                                         Medical
# F18139240                                         Medical
# F18139241                                         Medical
# F18139242                                         Medical
#
#              Initial CAD Event Call Type  \
# INCIDENT_NUM
# F11000010                        Medical
# F11000011                Carbon Monoxide
# F11000012                        Medical
# F11000013                 Emergency Fire
# F11000014                 Emergency Fire
# ...                                  ...
# F18139238                 Emergency Fire
# F18139239                        Medical
# F18139240                        Medical
# F18139241                        Medical
# F18139242                        Medical
#
#                                             Final Incident Type  \
# INCIDENT_NUM
# F11000010                                    89 - Other Medical
# F11000011                                    89 - Other Medical
# F11000012                                    89 - Other Medical
# F11000013     03 - NO LOSS OUTDOOR fire (exc: Sus.arson,vand...
# F11000014                  33 - Human - Malicious intent, prank
# ...                                                         ...
# F18139238                  33 - Human - Malicious intent, prank
# F18139239                                    89 - Other Medical
# F18139240                                    89 - Other Medical
# F18139241                                    89 - Other Medical
# F18139242                                    89 - Other Medical
#
#               Event Alarm Level                            Call Source  \
# INCIDENT_NUM
# F11000010                     1                    03 - From Ambulance
# F11000011                     1                               01 - 911
# F11000012                     1                    03 - From Ambulance
# F11000013                     1                               01 - 911
# F11000014                     1  05 - Telephone from Monitoring Agency
# ...                         ...                                    ...
# F18139238                     0  05 - Telephone from Monitoring Agency
# F18139239                     0                    03 - From Ambulance
# F18139240                     0                    03 - From Ambulance
# F18139241                     0                    03 - From Ambulance
# F18139242                     0                    03 - From Ambulance
#
#               Incident Station Area  Incident Ward   LATITUDE  Longitude  \
# INCIDENT_NUM
# F11000010                     342.0              9  43.679099 -79.461761
# F11000011                     131.0             15  43.726342 -79.396401
# F11000012                     324.0             14  43.668548 -79.335324
# F11000013                     345.0              9  43.657123 -79.434313
# F11000014                     142.0              7  43.759840 -79.516182
# ...                             ...            ...        ...        ...
# F18139238                     312.0             11  43.667162 -79.401539
# F18139239                     442.0              5   0.000000   0.000000
# F18139240                     322.0             14   0.000000   0.000000
# F18139241                     442.0              2   0.000000   0.000000
# F18139242                     234.0             24   0.000000   0.000000
#
#                                     Intersection       TFS Alarm Time  \
# INCIDENT_NUM
# F11000010        Silverthorn Ave / Turnberry Ave  2011-01-01 00:03:43
# F11000011     Lawrence Ave E / Mount Pleasant Rd  2011-01-01 00:03:55
# F11000012                 Endean Ave / Jones Ave  2011-01-01 00:05:03
# F11000013        Dufferin St / Dufferin Park Ave  2011-01-01 00:04:46
# F11000014             Driftwood Ave / Wilmont Dr  2011-01-01 00:06:07
# ...                                          ...                  ...
# F18139238                  Bloor St W / Huron St  2018-12-31 23:55:07
# F18139239                                    M6M  2018-12-31 23:56:38
# F18139240                                    M4J  2018-12-31 23:56:52
# F18139241                                    M9P  2018-12-31 23:59:30
# F18139242                                    M1E  2018-12-31 23:59:41
#
#                  TFS Arrival Time Last TFS Unit Clear Time  Persons Rescued  \
# INCIDENT_NUM
# F11000010     2011-01-01 00:10:02      2011-01-01 00:31:18              0.0
# F11000011     2011-01-01 00:09:02      2011-01-01 00:15:13              0.0
# F11000012     2011-01-01 00:09:34      2011-01-01 00:27:11              0.0
# F11000013     2011-01-01 00:10:46      2011-01-01 00:20:39              0.0
# F11000014     2011-01-01 00:11:03      2011-01-01 00:21:11              0.0
# ...                           ...                      ...              ...
# F18139238     2018-12-31 23:59:33      2019-01-01 00:06:22              0.0
# F18139239     2019-01-01 00:02:17      2019-01-01 00:04:57              0.0
# F18139240     2019-01-01 00:03:32      2019-01-01 00:07:43              0.0
# F18139241     2019-01-01 00:07:13      2019-01-01 00:10:05              0.0
# F18139242     2019-01-01 00:06:29      2019-01-01 00:40:58              0.0
#
#                         DATETIME                             lat_long  \
# INCIDENT_NUM
# F11000010    2011-01-01 00:03:43   (43.679098579, -79.46176085399999)
# F11000011    2011-01-01 00:03:55        (43.726342492, -79.396400551)
# F11000012    2011-01-01 00:05:03         (43.66854833, -79.335324059)
# F11000013    2011-01-01 00:04:46     (43.6571226, -79.43431345399999)
# F11000014    2011-01-01 00:06:07  (43.759840161999996, -79.516182424)
# ...                          ...                                  ...
# F18139238    2018-12-31 23:55:07  (43.667161863000004, -79.401538955)
# F18139239    2018-12-31 23:56:38                           (0.0, 0.0)
# F18139240    2018-12-31 23:56:52                           (0.0, 0.0)
# F18139241    2018-12-31 23:59:30                           (0.0, 0.0)
# F18139242    2018-12-31 23:59:41                           (0.0, 0.0)
#
#               FIRE_STATION_CLOSEST
# INCIDENT_NUM
# F11000010                      342
# F11000011                      131
# F11000012                      324
# F11000013                      345
# F11000014                      142
# ...                            ...
# F18139238                      344
# F18139239                      215
# F18139240                      215
# F18139241                      215
# F18139242                      215
#
# [975113 rows x 17 columns]

# %% [markdown]
# # 5c
# # Closest Toronto Fire Hydrant
# # NOT DONE AS IT WILL TAKE ~ 1000 hours to complete with my resources (~42 days)

# %% [markdown]
# # 6
# # Manipulations of Fire Incidents Dataset
# - The Final .csv file is not ready yet
#     - some manipulations are required

# %% [markdown]
# # 6a
# # Create Minutes to Arrival and Minutes to Leave Columns
# - How long did it take for Fire Services to arrive on location
# - How long did it take for them to leave the location after arriving

# %%
# get the number of minutes it took for Fire Services to arrive to the emergency
df_slice["MINUTES_ARRIVAL"] = np.around((pd.to_datetime(df_slice["TFS Arrival Time"]) -
               pd.to_datetime(df_slice["TFS Alarm Time"])) / np.timedelta64(1, "m"), decimals=3)

# get the number of minutes after arriving it takes for the Fire Services to leave
df_slice["MINUTES_LEAVE"] = np.around((pd.to_datetime(df_slice["Last TFS Unit Clear Time"]) -
               pd.to_datetime(df_slice["TFS Arrival Time"])) / np.timedelta64(1, "m"), decimals=3)
df_slice.head()
# Out:
#                          Initial CAD Event Type Initial CAD Event Call Type  \
# INCIDENT_NUM
# F11000010                               Medical                     Medical
# F11000011                               Medical             Carbon Monoxide
# F11000012                               Medical                     Medical
# F11000013            FIG - Fire - Grass/Rubbish              Emergency Fire
# F11000014     FAHR - Alarm Highrise Residential              Emergency Fire
#
#                                             Final Incident Type  \
# INCIDENT_NUM
# F11000010                                    89 - Other Medical
# F11000011                                    89 - Other Medical
# F11000012                                    89 - Other Medical
# F11000013     03 - NO LOSS OUTDOOR fire (exc: Sus.arson,vand...
# F11000014                  33 - Human - Malicious intent, prank
#
#               Event Alarm Level                            Call Source  \
# INCIDENT_NUM
# F11000010                     1                    03 - From Ambulance
# F11000011                     1                               01 - 911
# F11000012                     1                    03 - From Ambulance
# F11000013                     1                               01 - 911
# F11000014                     1  05 - Telephone from Monitoring Agency
#
#               Incident Station Area  Incident Ward   LATITUDE  Longitude  \
# INCIDENT_NUM
# F11000010                     342.0              9  43.679099 -79.461761
# F11000011                     131.0             15  43.726342 -79.396401
# F11000012                     324.0             14  43.668548 -79.335324
# F11000013                     345.0              9  43.657123 -79.434313
# F11000014                     142.0              7  43.759840 -79.516182
#
#                                     Intersection       TFS Alarm Time  \
# INCIDENT_NUM
# F11000010        Silverthorn Ave / Turnberry Ave  2011-01-01 00:03:43
# F11000011     Lawrence Ave E / Mount Pleasant Rd  2011-01-01 00:03:55
# F11000012                 Endean Ave / Jones Ave  2011-01-01 00:05:03
# F11000013        Dufferin St / Dufferin Park Ave  2011-01-01 00:04:46
# F11000014             Driftwood Ave / Wilmont Dr  2011-01-01 00:06:07
#
#                  TFS Arrival Time Last TFS Unit Clear Time  Persons Rescued  \
# INCIDENT_NUM
# F11000010     2011-01-01 00:10:02      2011-01-01 00:31:18              0.0
# F11000011     2011-01-01 00:09:02      2011-01-01 00:15:13              0.0
# F11000012     2011-01-01 00:09:34      2011-01-01 00:27:11              0.0
# F11000013     2011-01-01 00:10:46      2011-01-01 00:20:39              0.0
# F11000014     2011-01-01 00:11:03      2011-01-01 00:21:11              0.0
#
#                         DATETIME                             lat_long  \
# INCIDENT_NUM
# F11000010    2011-01-01 00:03:43   (43.679098579, -79.46176085399999)
# F11000011    2011-01-01 00:03:55        (43.726342492, -79.396400551)
# F11000012    2011-01-01 00:05:03         (43.66854833, -79.335324059)
# F11000013    2011-01-01 00:04:46     (43.6571226, -79.43431345399999)
# F11000014    2011-01-01 00:06:07  (43.759840161999996, -79.516182424)
#
#               FIRE_STATION_CLOSEST  MINUTES_ARRIVAL  MINUTES_LEAVE
# INCIDENT_NUM
# F11000010                      342            6.317         21.267
# F11000011                      131            5.117          6.183
# F11000012                      324            4.517         17.617
# F11000013                      345            6.000          9.883
# F11000014                      142            4.933         10.133

# %% [markdown]
# # 6b
# # Rename and Drop Columns and Change Datatypes
# - some data cleaning before writing to .csv file

# %%
# get datatypes of columns
df_slice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 975113 entries, F11000010 to F18139242
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Initial CAD Event Type       975113 non-null  object
#  1   Initial CAD Event Call Type  975113 non-null  object
#  2   Final Incident Type          975065 non-null  object
#  3   Event Alarm Level            975113 non-null  int64
#  4   Call Source                  975043 non-null  object
#  5   Incident Station Area        975052 non-null  float64
#  6   Incident Ward                975113 non-null  int64
#  7   LATITUDE                     975113 non-null  float64
#  8   Longitude                    975113 non-null  float64
#  9   Intersection                 975112 non-null  object
#  10  TFS Alarm Time               975113 non-null  object
#  11  TFS Arrival Time             951654 non-null  object
#  12  Last TFS Unit Clear Time     975109 non-null  object
#  13  Persons Rescued              975045 non-null  float64
#  14  DATETIME                     975113 non-null  datetime64[ns]
#  15  lat_long                     975113 non-null  object
#  16  FIRE_STATION_CLOSEST         975113 non-null  int64
#  17  MINUTES_ARRIVAL              951654 non-null  float64
#  18  MINUTES_LEAVE                951650 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(9)
# memory usage: 148.8+ MB

# %%
# There are some null values in "Incident Station Area" that one can infer from
# "FIRE_STATION_CLOSEST"
df_slice["Incident Station Area"].loc[df_slice["Incident Station Area"].isnull()] = \
            df_slice["FIRE_STATION_CLOSEST"].loc[df_slice["Incident Station Area"].isnull()]
# Out:
# C:\Users\owner\.conda\envs\geo_env\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# rename some columns in pandas
df_slice = df_slice.rename(columns={
    "Incident Station Area" : "FIRE_STATION",
    "Longitude" : "LONGITUDE",
    "Initial CAD Event Type" : "CAD_TYPE",
    "Initial CAD Event Call Type" : "CAD_CALL_TYPE",
    "Final Incident Type" : "FINAL_TYPE",
    "Event Alarm Level" : "ALARM_LEVEL",
    "Call Source" : "CALL_SOURCE",
    "Persons Rescued" : "PERSONS_RESCUED"
    })

# %%
# Drop some useless columns in the DataFrame
df_slice = df_slice.drop(columns=["Intersection", "TFS Alarm Time", "TFS Arrival Time",
                                 "Last TFS Unit Clear Time", "lat_long", "Incident Ward"])

# %%
# lets look at our changes
df_slice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 975113 entries, F11000010 to F18139242
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   CAD_TYPE              975113 non-null  object
#  1   CAD_CALL_TYPE         975113 non-null  object
#  2   FINAL_TYPE            975065 non-null  object
#  3   ALARM_LEVEL           975113 non-null  int64
#  4   CALL_SOURCE           975043 non-null  object
#  5   FIRE_STATION          975113 non-null  float64
#  6   LATITUDE              975113 non-null  float64
#  7   LONGITUDE             975113 non-null  float64
#  8   PERSONS_RESCUED       975045 non-null  float64
#  9   DATETIME              975113 non-null  datetime64[ns]
#  10  FIRE_STATION_CLOSEST  975113 non-null  int64
#  11  MINUTES_ARRIVAL       951654 non-null  float64
#  12  MINUTES_LEAVE         951650 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(4)
# memory usage: 104.2+ MB

# %%
# change datatype of several columns in dataframe
df_slice["FIRE_STATION"] = df_slice["FIRE_STATION"].astype("int64")

# %%
# lets have a look at the entire DataFrame
from IPython.display import display

with pd.option_context('display.max_columns', None):
    display(df_slice)
# Out:
#                                                  CAD_TYPE    CAD_CALL_TYPE  \
# INCIDENT_NUM
# F11000010                                         Medical          Medical
# F11000011                                         Medical  Carbon Monoxide
# F11000012                                         Medical          Medical
# F11000013                      FIG - Fire - Grass/Rubbish   Emergency Fire
# F11000014               FAHR - Alarm Highrise Residential   Emergency Fire
# ...                                                   ...              ...
# F18139238     FAHRD - Alarm Highrise Residential Downtown   Emergency Fire
# F18139239                                         Medical          Medical
# F18139240                                         Medical          Medical
# F18139241                                         Medical          Medical
# F18139242                                         Medical          Medical
#
#                                                      FINAL_TYPE  ALARM_LEVEL  \
# INCIDENT_NUM
# F11000010                                    89 - Other Medical            1
# F11000011                                    89 - Other Medical            1
# F11000012                                    89 - Other Medical            1
# F11000013     03 - NO LOSS OUTDOOR fire (exc: Sus.arson,vand...            1
# F11000014                  33 - Human - Malicious intent, prank            1
# ...                                                         ...          ...
# F18139238                  33 - Human - Malicious intent, prank            0
# F18139239                                    89 - Other Medical            0
# F18139240                                    89 - Other Medical            0
# F18139241                                    89 - Other Medical            0
# F18139242                                    89 - Other Medical            0
#
#                                         CALL_SOURCE  FIRE_STATION   LATITUDE  \
# INCIDENT_NUM
# F11000010                       03 - From Ambulance           342  43.679099
# F11000011                                  01 - 911           131  43.726342
# F11000012                       03 - From Ambulance           324  43.668548
# F11000013                                  01 - 911           345  43.657123
# F11000014     05 - Telephone from Monitoring Agency           142  43.759840
# ...                                             ...           ...        ...
# F18139238     05 - Telephone from Monitoring Agency           312  43.667162
# F18139239                       03 - From Ambulance           442   0.000000
# F18139240                       03 - From Ambulance           322   0.000000
# F18139241                       03 - From Ambulance           442   0.000000
# F18139242                       03 - From Ambulance           234   0.000000
#
#               LONGITUDE  PERSONS_RESCUED            DATETIME  \
# INCIDENT_NUM
# F11000010    -79.461761              0.0 2011-01-01 00:03:43
# F11000011    -79.396401              0.0 2011-01-01 00:03:55
# F11000012    -79.335324              0.0 2011-01-01 00:05:03
# F11000013    -79.434313              0.0 2011-01-01 00:04:46
# F11000014    -79.516182              0.0 2011-01-01 00:06:07
# ...                 ...              ...                 ...
# F18139238    -79.401539              0.0 2018-12-31 23:55:07
# F18139239      0.000000              0.0 2018-12-31 23:56:38
# F18139240      0.000000              0.0 2018-12-31 23:56:52
# F18139241      0.000000              0.0 2018-12-31 23:59:30
# F18139242      0.000000              0.0 2018-12-31 23:59:41
#
#               FIRE_STATION_CLOSEST  MINUTES_ARRIVAL  MINUTES_LEAVE
# INCIDENT_NUM
# F11000010                      342            6.317         21.267
# F11000011                      131            5.117          6.183
# F11000012                      324            4.517         17.617
# F11000013                      345            6.000          9.883
# F11000014                      142            4.933         10.133
# ...                            ...              ...            ...
# F18139238                      344            4.433          6.817
# F18139239                      215            5.650          2.667
# F18139240                      215            6.667          4.183
# F18139241                      215            7.717          2.867
# F18139242                      215            6.800         34.483
#
# [975113 rows x 13 columns]

# %%
# reorder the columns to a more pleasing order
df_slice = df_slice.loc[:, 
            [
                'DATETIME', 'MINUTES_ARRIVAL', 'MINUTES_LEAVE',
                'FIRE_STATION', 'FIRE_STATION_CLOSEST', 'LATITUDE',
                'LONGITUDE',
                'CAD_TYPE', 'CAD_CALL_TYPE', 'FINAL_TYPE',
                'ALARM_LEVEL', 'CALL_SOURCE', 'PERSONS_RESCUED'
            ]]

with pd.option_context('display.max_columns', None):
    display(df_slice)
# Out:
#                         DATETIME  MINUTES_ARRIVAL  MINUTES_LEAVE  \
# INCIDENT_NUM
# F11000010    2011-01-01 00:03:43            6.317         21.267
# F11000011    2011-01-01 00:03:55            5.117          6.183
# F11000012    2011-01-01 00:05:03            4.517         17.617
# F11000013    2011-01-01 00:04:46            6.000          9.883
# F11000014    2011-01-01 00:06:07            4.933         10.133
# ...                          ...              ...            ...
# F18139238    2018-12-31 23:55:07            4.433          6.817
# F18139239    2018-12-31 23:56:38            5.650          2.667
# F18139240    2018-12-31 23:56:52            6.667          4.183
# F18139241    2018-12-31 23:59:30            7.717          2.867
# F18139242    2018-12-31 23:59:41            6.800         34.483
#
#               FIRE_STATION  FIRE_STATION_CLOSEST   LATITUDE  LONGITUDE  \
# INCIDENT_NUM
# F11000010              342                   342  43.679099 -79.461761
# F11000011              131                   131  43.726342 -79.396401
# F11000012              324                   324  43.668548 -79.335324
# F11000013              345                   345  43.657123 -79.434313
# F11000014              142                   142  43.759840 -79.516182
# ...                    ...                   ...        ...        ...
# F18139238              312                   344  43.667162 -79.401539
# F18139239              442                   215   0.000000   0.000000
# F18139240              322                   215   0.000000   0.000000
# F18139241              442                   215   0.000000   0.000000
# F18139242              234                   215   0.000000   0.000000
#
#                                                  CAD_TYPE    CAD_CALL_TYPE  \
# INCIDENT_NUM
# F11000010                                         Medical          Medical
# F11000011                                         Medical  Carbon Monoxide
# F11000012                                         Medical          Medical
# F11000013                      FIG - Fire - Grass/Rubbish   Emergency Fire
# F11000014               FAHR - Alarm Highrise Residential   Emergency Fire
# ...                                                   ...              ...
# F18139238     FAHRD - Alarm Highrise Residential Downtown   Emergency Fire
# F18139239                                         Medical          Medical
# F18139240                                         Medical          Medical
# F18139241                                         Medical          Medical
# F18139242                                         Medical          Medical
#
#                                                      FINAL_TYPE  ALARM_LEVEL  \
# INCIDENT_NUM
# F11000010                                    89 - Other Medical            1
# F11000011                                    89 - Other Medical            1
# F11000012                                    89 - Other Medical            1
# F11000013     03 - NO LOSS OUTDOOR fire (exc: Sus.arson,vand...            1
# F11000014                  33 - Human - Malicious intent, prank            1
# ...                                                         ...          ...
# F18139238                  33 - Human - Malicious intent, prank            0
# F18139239                                    89 - Other Medical            0
# F18139240                                    89 - Other Medical            0
# F18139241                                    89 - Other Medical            0
# F18139242                                    89 - Other Medical            0
#
#                                         CALL_SOURCE  PERSONS_RESCUED
# INCIDENT_NUM
# F11000010                       03 - From Ambulance              0.0
# F11000011                                  01 - 911              0.0
# F11000012                       03 - From Ambulance              0.0
# F11000013                                  01 - 911              0.0
# F11000014     05 - Telephone from Monitoring Agency              0.0
# ...                                             ...              ...
# F18139238     05 - Telephone from Monitoring Agency              0.0
# F18139239                       03 - From Ambulance              0.0
# F18139240                       03 - From Ambulance              0.0
# F18139241                       03 - From Ambulance              0.0
# F18139242                       03 - From Ambulance              0.0
#
# [975113 rows x 13 columns]

# %%
# write to .csv and to a .csv.zip file
PATH_FINAL_CSV = os.path.join(FIRE_PROCESSED_UNZIPPED_DIRECTORY, "2011-2018_Toronto_Fire_Incidents_PROCESSED.csv")

# write to .csv
df_slice.to_csv(PATH_FINAL_CSV)

# %% [markdown]
# # 7
# # Creation of Zipped CSV Files

# %%
# write fire_incident data to a .csv.bz2 (compressed file)
PATH_FIRE_FINAL_CSV = os.path.join(FIRE_PROCESSED_UNZIPPED_DIRECTORY, "2011-2018_Toronto_Fire_Incidents_PROCESSED.csv")

# read the csv into a DataFrame
df_fire = pd.read_csv(PATH_FIRE_FINAL_CSV, parse_dates=["DATETIME"],
                     index_col="INCIDENT_NUM")

# write the csv to a csv.bz2 (compressed file)
PATH_FIRE_FINAL_CSV_BZ2 = os.path.join(FIRE_PROCESSED_ZIPPED_DIRECTORY, "2011-2018_Toronto_Fire_Incidents_PROCESSED.csv.bz2")
df_fire.to_csv(PATH_FIRE_FINAL_CSV_BZ2, compression='bz2')

df_fire.head()
# Out:
#                         DATETIME  MINUTES_ARRIVAL  MINUTES_LEAVE  \
# INCIDENT_NUM
# F11000010    2011-01-01 00:03:43            6.317         21.267
# F11000011    2011-01-01 00:03:55            5.117          6.183
# F11000012    2011-01-01 00:05:03            4.517         17.617
# F11000013    2011-01-01 00:04:46            6.000          9.883
# F11000014    2011-01-01 00:06:07            4.933         10.133
#
#               FIRE_STATION  FIRE_STATION_CLOSEST   LATITUDE  LONGITUDE  \
# INCIDENT_NUM
# F11000010              342                   342  43.679099 -79.461761
# F11000011              131                   131  43.726342 -79.396401
# F11000012              324                   324  43.668548 -79.335324
# F11000013              345                   345  43.657123 -79.434313
# F11000014              142                   142  43.759840 -79.516182
#
#                                        CAD_TYPE    CAD_CALL_TYPE  \
# INCIDENT_NUM
# F11000010                               Medical          Medical
# F11000011                               Medical  Carbon Monoxide
# F11000012                               Medical          Medical
# F11000013            FIG - Fire - Grass/Rubbish   Emergency Fire
# F11000014     FAHR - Alarm Highrise Residential   Emergency Fire
#
#                                                      FINAL_TYPE  ALARM_LEVEL  \
# INCIDENT_NUM
# F11000010                                    89 - Other Medical            1
# F11000011                                    89 - Other Medical            1
# F11000012                                    89 - Other Medical            1
# F11000013     03 - NO LOSS OUTDOOR fire (exc: Sus.arson,vand...            1
# F11000014                  33 - Human - Malicious intent, prank            1
#
#                                         CALL_SOURCE  PERSONS_RESCUED
# INCIDENT_NUM
# F11000010                       03 - From Ambulance              0.0
# F11000011                                  01 - 911              0.0
# F11000012                       03 - From Ambulance              0.0
# F11000013                                  01 - 911              0.0
# F11000014     05 - Telephone from Monitoring Agency              0.0

# %%
# write toronto_weather data to a .csv.bz2 (compressed file)
PATH_WEATHER_FINAL_CSV = os.path.join(WEATHER_PROCESSED_UNZIPPED_DIRECTORY, "2010-2020_Toronto_Weather.csv")

# read the csv into a DataFrame
df_weather = pd.read_csv(PATH_WEATHER_FINAL_CSV, parse_dates=["DATE"],
                        index_col="DATE")

# write the csv to a csv.bz2 (compressed file)
PATH_WEATHER_FINAL_CSV_BZ2 = os.path.join(WEATHER_PROCESSED_ZIPPED_DIRECTORY, "2010-2020_Toronto_Weather.csv.bz2")
df_weather.to_csv(PATH_WEATHER_FINAL_CSV_BZ2, compression='bz2')

df_weather.head()
# Out:
#             MAX_TEMP  MIN_TEMP  MEAN_TEMP    HDD  CDD  RAIN_MM  PRECIP_MM  \
# DATE
# 2010-01-01       1.9      -9.9      -3.00  21.00  0.0      0.0       0.63
# 2010-01-02      -9.7     -18.5     -14.05  32.05  0.0      0.0       0.33
# 2010-01-03      -9.3     -17.0     -12.90  30.90  0.0      0.0       1.90
# 2010-01-04      -6.7     -13.5      -9.85  27.85  0.0      0.0       0.27
# 2010-01-05      -3.6     -12.5      -7.65  25.65  0.0      0.0       1.30
#
#             SNOW_CM
# DATE
# 2010-01-01      0.0
# 2010-01-02      1.0
# 2010-01-03      1.0
# 2010-01-04      3.5
# 2010-01-05      4.5

# %%
# write toronto_weather data to a .csv.bz2 (compressed file)
PATH_STATIONS_FINAL_CSV = os.path.join(STATIONS_PROCESSED_UNZIPPED_DIRECTORY,
                                  "Toronto_Fire_Station_Locations_PROCESSED.csv")

# read the csv into a DataFrame
df_locations = pd.read_csv(PATH_STATIONS_FINAL_CSV, index_col="INDEX")

# write the csv to a csv.bz2 (compressed file)
PATH_STATIONS_FINAL_CSV_BZ2 = os.path.join(STATIONS_PROCESSED_ZIPPED_DIRECTORY, "Toronto_Fire_Station_Locations.csv.bz2")
df_locations.to_csv(PATH_STATIONS_FINAL_CSV_BZ2, compression='bz2')

df_locations.head()
# Out:
#                    NAME              ADDRESS   LATITUDE  LONGITUDE  \
# INDEX
# 214    FIRE STATION 214    745 MEADOWVALE RD  43.794219 -79.163605
# 215    FIRE STATION 215  5318 LAWRENCE AVE E  43.777401 -79.148069
# 221    FIRE STATION 221  2575 EGLINTON AVE E  43.734799 -79.255066
# 222    FIRE STATION 222       755 WARDEN AVE  43.720408 -79.284094
# 223    FIRE STATION 223        116 DORSET RD  43.723965 -79.233264
#
#                         WARD_NAME     MUN_NAME
# INDEX
# 214         Scarborough East (44)  Scarborough
# 215         Scarborough East (44)  Scarborough
# 221    Scarborough Southwest (35)  Scarborough
# 222    Scarborough Southwest (35)  Scarborough
# 223    Scarborough Southwest (36)  Scarborough
