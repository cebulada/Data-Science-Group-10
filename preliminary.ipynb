# %% [markdown]
# # Just Dependencies

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. New York City CitiBike - [link](https://www.citibikenyc.com/system-data)

# %%
df = pd.read_csv('./data/01/202005-citibike-tripdata.csv.zip', compression='zip')
df.head(10)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           336  2020-05-01 00:01:06.3380  2020-05-01 00:06:42.9560
# 1           853  2020-05-01 00:01:08.1950  2020-05-01 00:15:21.2150
# 2            78  2020-05-01 00:01:08.5260  2020-05-01 00:02:27.0490
# 3          1185  2020-05-01 00:02:22.4380  2020-05-01 00:22:08.1220
# 4           272  2020-05-01 00:02:32.8280  2020-05-01 00:07:05.0880
# 5           412  2020-05-01 00:03:35.9370  2020-05-01 00:10:28.0640
# 6           925  2020-05-01 00:04:12.4690  2020-05-01 00:19:37.7330
# 7            75  2020-05-01 00:04:52.9410  2020-05-01 00:06:08.7980
# 8           170  2020-05-01 00:04:58.2180  2020-05-01 00:07:49.0400
# 9           594  2020-05-01 00:05:06.1270  2020-05-01 00:15:00.6320
#
#    start station id                     start station name  \
# 0              2017                        E 43 St & 2 Ave
# 1              3376                        E 65 St & 2 Ave
# ...

# %%
df.shape
# Out:
# (1487890, 15)

# %% [markdown]
# # 2. Ontario Lake Water Quality at Drinking Water Stations - [link](https://data.ontario.ca/dataset/lake-water-quality-at-drinking-water-intakes)

# %%
xls = pd.ExcelFile("./data/02/Lake_Erie_GLIP.xlsx")

# %%
sheet_names = xls.sheet_names
sheet_names
# Out:
# ['Amherstburg', 'Blenheim', 'Dunnville', 'Elgin', 'Rosehill', 'Union']

# %%
df_dict_water = {x:pd.read_excel(xls,x) for x in sheet_names}
df_dict_water[sheet_names[0]].head(10)
# Out:
#    MOE_SAMPLE_ID  MOE_RESULT_ID       LAKE   STATION  \
# 0         893952          14300  Lake Erie  20140004
# 1         893952          55219  Lake Erie  20140004
# 2         893952       13999851  Lake Erie  20140004
# 3         893952       13999853  Lake Erie  20140004
# 4         893952       13999855  Lake Erie  20140004
# 5         893952       13999857  Lake Erie  20140004
# 6         893952       13999858  Lake Erie  20140004
# 7         893952       13999860  Lake Erie  20140004
# 8         893952       13999861  Lake Erie  20140004
# 9         893952       13999862  Lake Erie  20140004
#
#                             LOCATION SAMPLING_DATE TEST_NAME  \
# 0  AMHERSTBURG DRINKING WATER SYSTEM    1976-02-18    NNO2FR
# 1  AMHERSTBURG DRINKING WATER SYSTEM    1976-02-18    NNOTFR
# 2  AMHERSTBURG DRINKING WATER SYSTEM    1976-02-18    CHLRAT
# 3  AMHERSTBURG DRINKING WATER SYSTEM    1976-02-18    CLIDUR
# 4  AMHERSTBURG DRINKING WATER SYSTEM    1976-02-18    NNHTFR
# ...

# %%
for x in sheet_names:
    print(df_dict_water[x].shape)
# Out:
# (23642, 12)
# (16173, 12)
# (24311, 12)
# (24985, 13)
# (22757, 13)
# (23959, 13)

# %% [markdown]
# # 3. Ontario Great Lake Sediment Chemistry = [link](https://data.ontario.ca/dataset/sediment-chemistry-great-lakes-nearshore-areas)

# %%
xls = pd.ExcelFile("./data/03/GLIS_SEDIMENT_CHEMISTRY.xlsx")

# %%
sheet_names = xls.sheet_names
sheet_names
# Out:
# ['Lake Huron Sediment Chemistry',
#  'Lake Erie Sediment Chemistry',
#  'Lake Ontario Sediment Chemistry',
#  'Lake Superior Sed Chemistry']

# %%
df_dict_sediment = {x:pd.read_excel(xls,x) for x in sheet_names}
df_dict_sediment[sheet_names[0]].head(10)
# Out:
#    Body of Water        Collect Date Sample No Matrix  Sample Type Code  \
# 0  DETROIT RIVER 2001-08-07 16:09:00  GL012406     SE                55
# 1  DETROIT RIVER 2001-08-07 16:09:00  GL012406     SE                55
# 2  DETROIT RIVER 2001-08-07 16:09:00  GL012406     SE                55
# 3  DETROIT RIVER 2001-08-07 16:09:00  GL012406     SE                55
# 4  DETROIT RIVER 2001-08-07 16:09:00  GL012406     SE                55
# 5  DETROIT RIVER 2001-08-07 16:09:00  GL012406     SE                55
# 6  DETROIT RIVER 2001-08-07 16:09:00  GL012406     SE                55
# 7  DETROIT RIVER 2001-08-07 16:09:00  GL012406     SE                55
# 8  DETROIT RIVER 2001-08-07 16:09:00  GL012406     SE                55
# 9  DETROIT RIVER 2001-08-07 16:09:00  GL012406     SE                55
#
#   Sample Description  Composite From  Composite To Composite Unit  Station No  \
# 0             SHIPEK               0          0.03              M  1000020176
# ...

# %%
for x in sheet_names:
    print(df_dict_sediment[x].shape)
# Out:
# (36462, 24)
# (23514, 24)
# (34318, 24)
# (19004, 24)

# %% [markdown]
# # 4. Bike Share Toronto Ridership Data - [link](https://open.toronto.ca/dataset/bike-share-toronto-ridership-data/)

# %%
df = pd.read_csv('./data/04/Bike Share Toronto Ridership_Q1 2018.csv')
df.head(10)
# Out:
#    trip_id  trip_duration_seconds  from_station_id trip_start_time  \
# 0  2383648                    393             7018   1/1/2018 0:47
# 1  2383649                    625             7184   1/1/2018 0:52
# 2  2383650                    233             7235   1/1/2018 0:55
# 3  2383651                   1138             7202   1/1/2018 0:57
# 4  2383652                    703             7004   1/1/2018 1:00
# 5  2383653                   1026             7078   1/1/2018 1:07
# 6  2383654                    274             7021   1/1/2018 1:33
# 7  2383655                    764             7046   1/1/2018 1:34
# 8  2383657                    237             7044   1/1/2018 1:37
# 9  2383658                    180             7198   1/1/2018 1:38
#
#                          from_station_name trip_stop_time  to_station_id  \
# 0                   Bremner Blvd / Rees St  1/1/2018 0:54           7176
# 1               Ossington Ave / College St  1/1/2018 1:03           7191
# ...

# %%
df.shape
# Out:
# (178559, 9)

# %% [markdown]
# # 5. Toronto Daily Homeless Shelter Occupance - [link](https://open.toronto.ca/dataset/daily-shelter-occupancy/)

# %%
df = pd.read_csv('./data/05/Daily shelter occupancy current.csv')
df.head(10)
# Out:
#        _id       OCCUPANCY_DATE    SECTOR SHELTER_POSTAL_CODE  CAPACITY  \
# 0  2052256  2020-01-01T00:00:00     Women             M5S 2P1         0
# 1  2052257  2020-01-01T00:00:00  Families             M5S 2P1       560
# 2  2052258  2020-01-01T00:00:00  Families             M5S 2P1       888
# 3  2052259  2020-01-01T00:00:00     Co-ed             M5S 2P1        16
# 4  2052260  2020-01-01T00:00:00     Women             M5S 2P1         2
# 5  2052261  2020-01-01T00:00:00       Men             M6H 3Z5        82
# 6  2052262  2020-01-01T00:00:00       Men             M6H 3Z5        42
# 7  2052263  2020-01-01T00:00:00  Families             M6G 3B1        76
# 8  2052264  2020-01-01T00:00:00  Families             M1P 4V8       210
# 9  2052265  2020-01-01T00:00:00  Families             M1P 4V8         0
#
#   SHELTER_PROVINCE                     FACILITY_NAME  \
# 0               ON   COSTI - Radisson Hotel (Single)
# 1               ON  COSTI - Toronto Plaza Hotel(Fam)
# ...

# %%
df.shape
# Out:
# (21704, 15)

# %% [markdown]
# # 6. Toronto Fire Incidents - [link](https://open.toronto.ca/dataset/fire-incidents/)

# %%
df = pd.read_csv('./data/06/Fire Incidents Data.csv')
df.head(10)
# Out:
#       _id                                     Area_of_Origin  \
# 0  649265                                   81 - Engine Area
# 1  649266                 75 - Trash, rubbish area (outside)
# 2  649267                                                NaN
# 3  649268                 75 - Trash, rubbish area (outside)
# 4  649269                                                NaN
# 5  649270                                   81 - Engine Area
# 6  649271  22 - Sleeping Area or Bedroom (inc. patients r...
# 7  649272           55 - Mechanical/Electrical Services Room
# 8  649273                                        28 - Office
# 9  649274                                                NaN
#
#            Building_Status                          Business_Impact  \
# 0                      NaN                                      NaN
# 1                      NaN                                      NaN
# 2                      NaN                                      NaN
# ...

# %%
df.shape
# Out:
# (17536, 43)

# %% [markdown]
# # 7. Toronto Parking Data - [link](https://open.toronto.ca/dataset/parking-tickets/)

# %%
df = pd.read_csv('./data/07/Parking_Tags_Data_2018_1.csv')
df.head(10)
# Out:
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***92517            20180101               16
# 1          ***71708            20180101               29
# 2          ***92311            20180101               29
# 3          ***92312            20180101               29
# 4          ***71709            20180101               29
# 5          ***73023            20180101                3
# 6          ***73024            20180101                3
# 7          ***92313            20180101               29
# 8          ***71710            20180101               29
# 9          ***73025            20180101                3
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0   PARK-WITHIN 9M INTERSECT ROAD               50                 0.0
# 1  PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 2  PARK PROHIBITED TIME NO PERMIT               30                 2.0
# ...

# %%
df.shape
# Out:
# (750000, 11)

# %% [markdown]
# # 8. Amazon Reviews Dataset - [link](https://s3.amazonaws.com/amazon-reviews-pds/tsv/index.txt)

# %%
df = pd.read_table('./data/08/amazon_reviews_us_Automotive_v1_00.tsv.gz', error_bad_lines=False)
df.head(10)
# Out:
# b'Skipping line 32293: expected 15 fields, saw 22\nSkipping line 37769: expected 15 fields, saw 22\n'
# b'Skipping line 93174: expected 15 fields, saw 22\nSkipping line 128815: expected 15 fields, saw 22\n'
# b'Skipping line 141887: expected 15 fields, saw 22\nSkipping line 147961: expected 15 fields, saw 22\nSkipping line 152729: expected 15 fields, saw 22\nSkipping line 162854: expected 15 fields, saw 22\nSkipping line 166656: expected 15 fields, saw 22\nSkipping line 182051: expected 15 fields, saw 22\n'
# b'Skipping line 220511: expected 15 fields, saw 22\nSkipping line 222466: expected 15 fields, saw 22\n'
# b'Skipping line 271740: expected 15 fields, saw 22\nSkipping line 290308: expected 15 fields, saw 22\nSkipping line 306805: expected 15 fields, saw 22\nSkipping line 310772: expected 15 fields, saw 22\nSkipping line 315182: expected 15 fields, saw 22\nSkipping line 323931: expected 15 fields, saw 22\n'
# ...

# %%
df.shape
# Out:
# (3510895, 15)
