# %%
import numpy as np
np.__version__
# Out:
# '1.18.1'

# %%
import pandas as pd
pd.__version__
# Out:
# '1.0.1'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.1.3'

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#!jupyter nbextension enable --py --sys-prefix widgetsnbextension
#!jupyter nbextension enable --py gmaps
#!jupyter nbextension enable --py --sys-prefix gmaps
#!jupyter labextension install @jupyter-widgets/jupyterlab-manager
#!jupyter lab build

# %%
import gmaps
gmaps.__version__
# Out:
# '0.9.0'

# %%
import requests
import os
import pprint as pp
from api_keys import google_api_key

# %%
# get the homeless_shelter directory
path = os.path.join(os.getcwd(), 'homeless_shelter')

# %%
# walk through the homeless_shelter directory
# to find the file "daily-shelter-occupancy-readme.xlsx"
for dirpath, subdirs, files in os.walk(path):
    subdirs[:] = [d for d in subdirs if d not in '.ipynb_checkpoints']
    for x in files:
        if x.split(".")[1] == "xlsx":
            metadata_path = os.path.join(dirpath, x)

# walk through the homeless_shelter directory
# to find the file paths "daily-shelter-occupancy-20XX-csv.csv"
file_paths = []
for dirpath, subdirs, files in os.walk(path):
    subdirs[:] = [d for d in subdirs if d not in '.ipynb_checkpoints']
    for x in files:
        if x.split(".")[1] == "csv":
            if x != "google_geocode_lats_lngs.csv":
                file_paths.append(os.path.join(dirpath, x))
file_paths.sort()

# metadata_path, a string, holds the pathway to the metadata
# file_paths, a list of strings, holds the pathway to each file

# %%
# homeless metadata dataframe
pd.set_option('max_colwidth', 400)
df_metadata = pd.read_excel(metadata_path)
df_metadata
# Out:
#              Field Name  \
# 0     Organization_name
# 1          Shelter_name
# 2         Facility_name
# 3          Program_name
# 4             Occupancy
# 5              Capacity
# 6        Occupancy_date
# 7      Shelter_province
# 8                Sector
# 9          Shelter_city
# 10      Shelter_address
# 11  Shelter_postal_code
#
#                                                                     Description  \
# 0                                                             Organization Name
# 1                                                      Name of the shelter site
# 2                                                          Name of the facility
# 3                                       Name of the program within the facility
# 4                          Number of homeless clients in the program at 4:00 AM
# 5   Maximum number of spaces available for homeless clients within the program.
# 6                                                              Date of the data
# 7                                                      Province of the shelter
# 8                                                    Clientele of the shelter
# 9                                                           City of the shelter
# 10                                                       Address of the shelter
# 11                                                   Postal code of the shelter
#
#                                                                                                                                                                                                                                                                                                                                                                                       Example
# 0                                                                                                                                                                                                                                                                                                      The registered name of the non-profit entity responsible \nfor the shelter operation.
# 1                                                                                                                           The shelter name generally delineates the subgroup within \nthe organization that is responsible for the shelter. For example the City of Toronto is the organization responsible for the shelters named: Women's Residence, Family Residence, Seaton House etc.
# 2                                                                                                                                                                         In some cases shelters share the same name but the actual service is provided in multiple facilities. For example Women's Residence has 3 facilities: the Alexandra Hotel, 63 Bellwoods and 674 Dundas Street West
# 3                                                                    Some shelters offer different programs or services within the same \nfacility. For example Seaton House offers emergency shelter on certain floors of 339 George Street but other floors within the same facility are dedicated to longer staying clients. In this example, the program name is the "Long Term" program.
# 4                                                                                                                                                                                                                                        Occupancy is a point in time number at 4 AM of the next day.\nFor example, the occupancy count of January 1st would be taken on January 2nd at 4 AM.
# 5   The term "spaces available" can mean a bed or a mat/cot. In the \nfamily sector it is possible to exceed available capacity depending on the bed configuration of each room. For example a family of five, who have small children, can elect to be accommodated in a room with four beds. This situation would keep the family united but would exceed the set capacity of the database.
# 6                                                                                                                                                                                                                                                                                                                                                                                         NaN
# 7                                                                                                                                                                                                                                                                                                                                                                                         NaN
# 8                                                                                                                                                                                                                                                                                                                                          Sector can be women, men, youth, co-ed, or family.
# 9                                                                                                                                                                                                                                                                                                                                                                                         NaN
# 10                                                                                                                                                                                                                                                                                                                                                                                        NaN
# 11                                                                                                                                                                                                                                                                                                                                                                                        NaN

# %%
# reset pandas default option
pd.reset_option('max_colwidth')

# %%
# read all 3 .csv files with data into a dictionary
df_dict = dict()
for x in file_paths:
    df_dict[x] = pd.read_csv(x, parse_dates=["OCCUPANCY_DATE"])

# %%
# get the shape of each dataframe
total_rows = 0
for y in df_dict.values():
    print(y.shape)
    total_rows += y.shape[0]
    
# and the total number of rows
total_rows
# Out:
# (38700, 13)
# (37770, 13)
# (39446, 13)
# 115916

# %%
# get the columns for each dataframe (3 in total)
for y in df_dict.values():
    print(y.columns)
# Out:
# Index(['_id', 'OCCUPANCY_DATE', 'ORGANIZATION_NAME', 'SHELTER_NAME',
#        'SHELTER_ADDRESS', 'SHELTER_CITY', 'SHELTER_PROVINCE',
#        'SHELTER_POSTAL_CODE', 'FACILITY_NAME', 'PROGRAM_NAME', 'SECTOR',
#        'OCCUPANCY', 'CAPACITY'],
#       dtype='object')
# Index(['_id', 'OCCUPANCY_DATE', 'ORGANIZATION_NAME', 'SHELTER_NAME',
#        'SHELTER_ADDRESS', 'SHELTER_CITY', 'SHELTER_PROVINCE',
#        'SHELTER_POSTAL_CODE', 'FACILITY_NAME', 'PROGRAM_NAME', 'SECTOR',
#        'OCCUPANCY', 'CAPACITY'],
#       dtype='object')
# Index(['_id', 'OCCUPANCY_DATE', 'ORGANIZATION_NAME', 'SHELTER_NAME',
#        'SHELTER_ADDRESS', 'SHELTER_CITY', 'SHELTER_PROVINCE',
#        'SHELTER_POSTAL_CODE', 'FACILITY_NAME', 'PROGRAM_NAME', 'SECTOR',
#        'OCCUPANCY', 'CAPACITY'],
#       dtype='object')

# %%
# prove that all the columns are equivalent
print("2017 and 2018: ",df_dict[file_paths[0]].columns == df_dict[file_paths[1]].columns)
print("2018 and 2019: ", df_dict[file_paths[1]].columns == df_dict[file_paths[2]].columns)
print("2017 and 2019: ", df_dict[file_paths[0]].columns == df_dict[file_paths[2]].columns)
# Out:
# 2017 and 2018:  [ True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# 2018 and 2019:  [ True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# 2017 and 2019:  [ True  True  True  True  True  True  True  True  True  True  True  True
#   True]

# %%
# lets create 1 dataframe from the 3
df = pd.concat([x for x in df_dict.values()])
df.head()
# Out:
#    _id OCCUPANCY_DATE                        ORGANIZATION_NAME  \
# 0    1     2017-01-01                 COSTI Immigrant Services
# 1    2     2017-01-01  Christie Ossington Neighbourhood Centre
# 2    3     2017-01-01  Christie Ossington Neighbourhood Centre
# 3    4     2017-01-01    Christie Refugee Welcome Centre, Inc.
# 4    5     2017-01-01                          City of Toronto
#
#                       SHELTER_NAME        SHELTER_ADDRESS SHELTER_CITY  \
# 0           COSTI Reception Centre  100 Lippincott Street      Toronto
# 1  Christie Ossington Men's Hostel   973 Lansdowne Avenue      Toronto
# 2  Christie Ossington Men's Hostel   973 Lansdowne Avenue      Toronto
# 3  Christie Refugee Welcome Centre     43 Christie Street      Toronto
# 4             Birchmount Residence     1673 Kingston Road      Toronto
#
#   SHELTER_PROVINCE SHELTER_POSTAL_CODE                    FACILITY_NAME  \
# 0               ON             M5S 2P1           COSTI Reception Centre
# 1               ON             M6H 3Z5  Christie Ossington Men's Hostel
# 2               ON             M6H 3Z5  Christie Ossington Men's Hostel
# 3               ON             M6G 3B1  Christie Refugee Welcome Centre
# 4               ON                 NaN  Birchmount Res 1673 Kingston Rd
#
#                                         PROGRAM_NAME    SECTOR  OCCUPANCY  \
# 0                   COSTI Reception Ctr CITY Program     Co-ed         16
# 1         Christie Ossington Extreme Weather Program       Men         13
# 2                    Christie Ossington Men's Hostel       Men         63
# 3  Christie Refugee Welcome Ctr - Settlement and ...  Families         66
# 4                               Birchmount Residence       Men         58
#
#    CAPACITY
# 0      16.0
# 1      17.0
# 2      63.0
# 3      70.0
# 4      60.0

# %%
# lets get the shape
df.shape
# Out:
# (115916, 13)

# %%
# lets get some info about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115916 entries, 0 to 39445
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   _id                  115916 non-null  int64
#  1   OCCUPANCY_DATE       115916 non-null  datetime64[ns]
#  2   ORGANIZATION_NAME    115916 non-null  object
#  3   SHELTER_NAME         115916 non-null  object
#  4   SHELTER_ADDRESS      115916 non-null  object
#  5   SHELTER_CITY         115916 non-null  object
#  6   SHELTER_PROVINCE     115916 non-null  object
#  7   SHELTER_POSTAL_CODE  110422 non-null  object
#  8   FACILITY_NAME        115916 non-null  object
#  9   PROGRAM_NAME         115916 non-null  object
#  10  SECTOR               115916 non-null  object
#  11  OCCUPANCY            115916 non-null  int64
#  12  CAPACITY             115573 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 12.4+ MB

# %%
# some summary statistics?
df.describe()
# Out:
#                  _id      OCCUPANCY       CAPACITY
# count  115916.000000  115916.000000  115573.000000
# mean    19325.915887      56.970211      60.528861
# std     11164.582502      83.188821      92.601212
# min         1.000000       0.000000       0.000000
# 25%      9660.000000      13.000000      16.000000
# 50%     19320.000000      37.000000      40.000000
# 75%     28979.250000      69.000000      71.000000
# max     39446.000000     826.000000     902.000000

# %%
# get list of null values
# postal codes are missing
df.isnull().sum()
# Out:
# _id                       0
# OCCUPANCY_DATE            0
# ORGANIZATION_NAME         0
# SHELTER_NAME              0
# SHELTER_ADDRESS           0
# SHELTER_CITY              0
# SHELTER_PROVINCE          0
# SHELTER_POSTAL_CODE    5494
# FACILITY_NAME             0
# PROGRAM_NAME              0
# SECTOR                    0
# OCCUPANCY                 0
# CAPACITY                343
# dtype: int64

# %%
# the dataset goes by multiple different dates
df["OCCUPANCY_DATE"].sample(10)
# Out:
# 26461   2019-09-04
# 10989   2019-04-13
# 6254    2018-03-01
# 28949   2018-10-06
# 11346   2017-04-18
# 3421    2018-02-02
# 21992   2018-07-29
# 4196    2017-09-02
# 17385   2018-06-15
# 36071   2018-12-15
# Name: OCCUPANCY_DATE, dtype: datetime64[ns]

# %%
# get the minimum date
df["OCCUPANCY_DATE"].min()
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
# get the maximum date
df["OCCUPANCY_DATE"].max()
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
# '_id' column appears to be unique for each row in each dataframe
# but through concatenation we get triplets of each value
df["_id"].unique()
# Out:
# array([    1,     2,     3, ..., 39444, 39445, 39446], dtype=int64)

# %%
# lets make a new id and drop _id
# and set id as our index
df["id"] = np.arange(1, len(df)+1)
df = df.drop(columns=["_id"])
df = df.set_index("id")
df.head()
# Out:
#    OCCUPANCY_DATE                        ORGANIZATION_NAME  \
# id
# 1      2017-01-01                 COSTI Immigrant Services
# 2      2017-01-01  Christie Ossington Neighbourhood Centre
# 3      2017-01-01  Christie Ossington Neighbourhood Centre
# 4      2017-01-01    Christie Refugee Welcome Centre, Inc.
# 5      2017-01-01                          City of Toronto
#
#                        SHELTER_NAME        SHELTER_ADDRESS SHELTER_CITY  \
# id
# 1            COSTI Reception Centre  100 Lippincott Street      Toronto
# 2   Christie Ossington Men's Hostel   973 Lansdowne Avenue      Toronto
# 3   Christie Ossington Men's Hostel   973 Lansdowne Avenue      Toronto
# 4   Christie Refugee Welcome Centre     43 Christie Street      Toronto
# 5              Birchmount Residence     1673 Kingston Road      Toronto
#
#    SHELTER_PROVINCE SHELTER_POSTAL_CODE                    FACILITY_NAME  \
# id
# 1                ON             M5S 2P1           COSTI Reception Centre
# 2                ON             M6H 3Z5  Christie Ossington Men's Hostel
# 3                ON             M6H 3Z5  Christie Ossington Men's Hostel
# 4                ON             M6G 3B1  Christie Refugee Welcome Centre
# 5                ON                 NaN  Birchmount Res 1673 Kingston Rd
#
#                                          PROGRAM_NAME    SECTOR  OCCUPANCY  \
# id
# 1                    COSTI Reception Ctr CITY Program     Co-ed         16
# 2          Christie Ossington Extreme Weather Program       Men         13
# 3                     Christie Ossington Men's Hostel       Men         63
# 4   Christie Refugee Welcome Ctr - Settlement and ...  Families         66
# 5                                Birchmount Residence       Men         58
#
#     CAPACITY
# id
# 1       16.0
# 2       17.0
# 3       63.0
# 4       70.0
# 5       60.0

# %%
# groupby on "SHELTER_ADDRESS" and "SHELTER_CITY" to get them as a DataFrame
df_locations = df.loc[:, ["SECTOR", "SHELTER_ADDRESS", "SHELTER_CITY"]].groupby(["SHELTER_ADDRESS", "SHELTER_CITY"]).count()
df_locations = df_locations.reset_index().loc[:, ["SHELTER_ADDRESS", "SHELTER_CITY"]]

# this allows us to generate a unique dataframe of addresses and associated cities
df_locations
# Out:
#           SHELTER_ADDRESS SHELTER_CITY
# 0   100 Lippincott Street      Toronto
# 1      101 Ontario Street      Toronto
# 2       107 Jarvis Street      Toronto
# 3        1076 Pape Avenue      Toronto
# 4     1161 Caledonia Road      Toronto
# ..                    ...          ...
# 60         87 Pembroke St      Toronto
# 61         875 Queen St E      Toronto
# 62    95 Wellesley St. E.      Toronto
# 63   973 Lansdowne Avenue      Toronto
# 64      Sherbourne Street      Toronto
#
# [65 rows x 2 columns]

# %%
# create a dictionary that will hold everything
response_dict = {
    "latitudes": [],
    "longitudes": [],
    "formatted_address" :[],
    "postal_code" : [],
    "json_responses" : [], 
    "SHELTER_ADDRESS": df_locations["SHELTER_ADDRESS"].values,
    "SHELTER_CITY": df_locations["SHELTER_CITY"].values
}

# characteristics for google maps geocode api calls
base = "https://maps.googleapis.com/maps/api/geocode/"
outputFormat = "json?"
api_key_phrase = f"&key={google_api_key}"
province = "Ontario"
country = "Canada"

# for loop going over each row of DataFrame
for x in range(len(response_dict["SHELTER_ADDRESS"])):
    # generate the HTML for HTTP API request
    address = response_dict["SHELTER_ADDRESS"][x]
    city = response_dict["SHELTER_CITY"][x]
    HTML_call = (f'{base}{outputFormat}address={address} {city} {province} '+
               f'{country}{api_key_phrase}')
    
    # get the response and turn it from json to a python dictionary
    response = requests.get(HTML_call).json()
    
    # use a try...except statement just in case any of these values cannot be found
    # for a given address
    try:
        response_dict["postal_code"].append(
            # look for types[0] == "postal_code" because some values
            # are missing postal codes
            next(item for item in response["results"][0]["address_components"] 
                if item["types"][0] == "postal_code"
                )["long_name"]
                                         )
        response_dict["latitudes"].append(
            response["results"][0]["geometry"]["location"]["lat"]
                                         )
        response_dict["longitudes"].append(
            response["results"][0]["geometry"]["location"]["lng"]
                                         )
        response_dict["formatted_address"].append(
            response["results"][0]["formatted_address"]
                                         )
        response_dict["json_responses"].append(response)
    except:
        response_dict["latitudes"].append(None)
        response_dict["longitudes"].append(None)
        response_dict["formatted_address"].append(None)
        response_dict["postal_code"].append(None)
        response_dict["json_responses"].append(response)

# %%
for index, value in response_dict.items():
    print(index, len(value))
# Out:
# latitudes 65
# longitudes 65
# formatted_address 65
# postal_code 65
# json_responses 65
# SHELTER_ADDRESS 65
# SHELTER_CITY 65

# %%
df_lats_longs = pd.DataFrame(response_dict)
df_lats_longs
# Out:
#     latitudes  longitudes                                  formatted_address  \
# 0   43.657677  -79.407047     100 Lippincott St, Toronto, ON M5S 2P1, Canada
# 1   43.654558  -79.366575        101 Ontario St, Toronto, ON M5A 2V2, Canada
# 2   43.652367  -79.372272         107 Jarvis St, Toronto, ON M5C 2H4, Canada
# 3   43.690910  -79.349663       1076 Pape Ave, East York, ON M4K 3W5, Canada
# 4   43.715653  -79.466609  1161 Caledonia Rd, North York, ON M6A 1J8, Canada
# ..        ...         ...                                                ...
# 60  43.659242  -79.372430        87 Pembroke St, Toronto, ON M5A 2N9, Canada
# 61  43.660007  -79.343222        875 Queen St E, Toronto, ON M4M 1J2, Canada
# 62  43.665864  -79.379215     95 Wellesley St E, Toronto, ON M4Y 2X9, Canada
# 63  43.666112  -79.446018     973 Lansdowne Ave, Toronto, ON M6H 3Z5, Canada
# 64        NaN         NaN                                               None
#
#    postal_code                                     json_responses  \
# 0      M5S 2P1  {'results': [{'address_components': [{'long_na...
# 1      M5A 2V2  {'results': [{'address_components': [{'long_na...
# 2      M5C 2H4  {'results': [{'address_components': [{'long_na...
# 3      M4K 3W5  {'results': [{'address_components': [{'long_na...
# 4      M6A 1J8  {'results': [{'address_components': [{'long_na...
# ..         ...                                                ...
# 60     M5A 2N9  {'results': [{'address_components': [{'long_na...
# 61     M4M 1J2  {'results': [{'address_components': [{'long_na...
# 62     M4Y 2X9  {'results': [{'address_components': [{'long_na...
# 63     M6H 3Z5  {'results': [{'address_components': [{'long_na...
# 64        None  {'results': [{'address_components': [{'long_na...
#
#           SHELTER_ADDRESS SHELTER_CITY
# 0   100 Lippincott Street      Toronto
# 1      101 Ontario Street      Toronto
# 2       107 Jarvis Street      Toronto
# 3        1076 Pape Avenue      Toronto
# 4     1161 Caledonia Road      Toronto
# ..                    ...          ...
# 60         87 Pembroke St      Toronto
# 61         875 Queen St E      Toronto
# 62    95 Wellesley St. E.      Toronto
# 63   973 Lansdowne Avenue      Toronto
# 64      Sherbourne Street      Toronto
#
# [65 rows x 7 columns]

# %%
geocode_df_path = os.path.join(os.path.dirname(file_paths[0]), "google_geocode_lats_lngs.csv")

# %%
# save it as a csv
df_lats_longs.to_csv(geocode_df_path, index=False)

# %%
df_merge = pd.merge(df, df_lats_longs, on="SHELTER_ADDRESS")
df_merge.head()
# Out:
#   OCCUPANCY_DATE         ORGANIZATION_NAME            SHELTER_NAME  \
# 0     2017-01-01  COSTI Immigrant Services  COSTI Reception Centre
# 1     2017-02-01  COSTI Immigrant Services  COSTI Reception Centre
# 2     2017-03-01  COSTI Immigrant Services  COSTI Reception Centre
# 3     2017-04-01  COSTI Immigrant Services  COSTI Reception Centre
# 4     2017-05-01  COSTI Immigrant Services  COSTI Reception Centre
#
#          SHELTER_ADDRESS SHELTER_CITY_x SHELTER_PROVINCE SHELTER_POSTAL_CODE  \
# 0  100 Lippincott Street        Toronto               ON             M5S 2P1
# 1  100 Lippincott Street        Toronto               ON             M5S 2P1
# 2  100 Lippincott Street        Toronto               ON             M5S 2P1
# 3  100 Lippincott Street        Toronto               ON             M5S 2P1
# 4  100 Lippincott Street        Toronto               ON             M5S 2P1
#
#             FACILITY_NAME                      PROGRAM_NAME SECTOR  OCCUPANCY  \
# 0  COSTI Reception Centre  COSTI Reception Ctr CITY Program  Co-ed         16
# 1  COSTI Reception Centre  COSTI Reception Ctr CITY Program  Co-ed         16
# 2  COSTI Reception Centre  COSTI Reception Ctr CITY Program  Co-ed         16
# 3  COSTI Reception Centre  COSTI Reception Ctr CITY Program  Co-ed         16
# 4  COSTI Reception Centre  COSTI Reception Ctr CITY Program  Co-ed         16
#
#    CAPACITY  latitudes  longitudes  \
# 0      16.0  43.657677  -79.407047
# 1      16.0  43.657677  -79.407047
# 2      16.0  43.657677  -79.407047
# 3      16.0  43.657677  -79.407047
# 4      16.0  43.657677  -79.407047
#
#                                 formatted_address postal_code  \
# 0  100 Lippincott St, Toronto, ON M5S 2P1, Canada     M5S 2P1
# 1  100 Lippincott St, Toronto, ON M5S 2P1, Canada     M5S 2P1
# 2  100 Lippincott St, Toronto, ON M5S 2P1, Canada     M5S 2P1
# 3  100 Lippincott St, Toronto, ON M5S 2P1, Canada     M5S 2P1
# 4  100 Lippincott St, Toronto, ON M5S 2P1, Canada     M5S 2P1
#
#                                       json_responses SHELTER_CITY_y
# 0  {'results': [{'address_components': [{'long_na...        Toronto
# 1  {'results': [{'address_components': [{'long_na...        Toronto
# 2  {'results': [{'address_components': [{'long_na...        Toronto
# 3  {'results': [{'address_components': [{'long_na...        Toronto
# 4  {'results': [{'address_components': [{'long_na...        Toronto

# %%
df_merge.isnull().sum()
# Out:
# OCCUPANCY_DATE            0
# ORGANIZATION_NAME         0
# SHELTER_NAME              0
# SHELTER_ADDRESS           0
# SHELTER_CITY_x            0
# SHELTER_PROVINCE          0
# SHELTER_POSTAL_CODE    5494
# FACILITY_NAME             0
# PROGRAM_NAME              0
# SECTOR                    0
# OCCUPANCY                 0
# CAPACITY                343
# latitudes              4382
# longitudes             4382
# formatted_address      4382
# postal_code            4382
# json_responses            0
# SHELTER_CITY_y            0
# dtype: int64

# %%
df_groupby2 = df_merge[["SHELTER_NAME", "FACILITY_NAME", "SHELTER_ADDRESS",
           "SHELTER_CITY_x", "postal_code", "latitudes", "longitudes",
           "OCCUPANCY", "CAPACITY"]]\
    .groupby(["SHELTER_NAME", "FACILITY_NAME", "SHELTER_ADDRESS",
               "SHELTER_CITY_x", "postal_code", "latitudes", "longitudes"])\
    .agg(["mean", "median", "std"]).reset_index()
df_groupby2
# Out:
#               SHELTER_NAME                     FACILITY_NAME  \
#
# 0     Birchmount Residence   Birchmount Res 1673 Kingston Rd
# 1       Birkdale Residence                Birkdale Residence
# 2       Birkdale Residence    Birkdale Residence Motel (Fam)
# 3       Birkdale Residence  Birkdale Residence Motel (Men's)
# 4       Birkdale Residence   Birkdale Residence Motel(Co-Ed)
# ..                     ...                               ...
# 115     YWCA-348 Davenport   YWCA - 348 Davenport Road Women
# 116     YWCA-348 Davenport   YWCA - 348 Davenport Road Youth
# 117  Youth Without Shelter   Youth w/o Shelter Emerg Shelter
# 118  Youth Without Shelter  Youth w/o Shltr Transitional Res
# 119      YouthLink Shelter        YouthLink - 747 Warden Ave
#
#          SHELTER_ADDRESS SHELTER_CITY_x postal_code  latitudes longitudes  \
#
# 0     1673 Kingston Road        Toronto     M1N 1S6  43.691569 -79.263923
# 1    1229 Ellesmere Road        Toronto     M1P 4V8  43.768282 -79.267447
# 2    1229 Ellesmere Road        Toronto     M1P 4V8  43.768282 -79.267447
# 3    1229 Ellesmere Road        Toronto     M1P 4V8  43.768282 -79.267447
# 4    1229 Ellesmere Road        Toronto     M1P 4V8  43.768282 -79.267447
# ..                   ...            ...         ...        ...        ...
# 115    348 Davenport Rd.        Toronto     M5R 1K6  43.675403 -79.401348
# 116    348 Davenport Rd.        Toronto     M5R 1K6  43.675403 -79.401348
# 117   6 Warrendale Court      Etobicoke     M9V 1P9  43.736293 -79.580427
# 118   6 Warrendale Court      Etobicoke     M9V 1P9  43.736293 -79.580427
# 119       747 Warden Ave        Toronto     M1L 4A8  43.717816 -79.282880
#
#       OCCUPANCY                       CAPACITY
#            mean median         std        mean median         std
# 0     57.621918   59.0    2.564838   60.000000   60.0    0.000000
# 1    173.078539  169.0   12.873355  168.522374  160.0   17.514768
# 2    235.522036  172.0  145.775502  289.513346  205.0  174.071090
# 3     15.720745   19.0    8.241798   25.821333   36.0   13.605056
# 4      1.473469    2.0    0.786874    2.000000    2.0    0.000000
# ..          ...    ...         ...         ...    ...         ...
# 115   37.446377   39.0    5.413500   38.104348   40.0    5.443217
# 116   14.240469   15.0    1.911484   14.835777   15.0    1.235270
# 117   32.605479   33.0    0.730360   33.000000   33.0    0.000000
# 118   19.550685   20.0    0.723677   19.961644   20.0    0.337196
# 119   22.394191   10.0   14.604210   23.595436   10.0   15.145319
#
# [120 rows x 13 columns]

# %%
df_groupby2.columns = ["SHELTER_NAME", "FACILITY_NAME", "SHELTER_ADDRESS",
                            "SHELTER_CITY_x", "postal_code", "latitudes",
                            "longitudes", "OCCUPANCY_mean", "OCCUPANCY_median", "OCCUPANCY_std",
                            "CAPACITY_mean", "CAPACITY_median", "CAPACITY_std"]
df_groupby2
# Out:
#               SHELTER_NAME                     FACILITY_NAME  \
# 0     Birchmount Residence   Birchmount Res 1673 Kingston Rd
# 1       Birkdale Residence                Birkdale Residence
# 2       Birkdale Residence    Birkdale Residence Motel (Fam)
# 3       Birkdale Residence  Birkdale Residence Motel (Men's)
# 4       Birkdale Residence   Birkdale Residence Motel(Co-Ed)
# ..                     ...                               ...
# 115     YWCA-348 Davenport   YWCA - 348 Davenport Road Women
# 116     YWCA-348 Davenport   YWCA - 348 Davenport Road Youth
# 117  Youth Without Shelter   Youth w/o Shelter Emerg Shelter
# 118  Youth Without Shelter  Youth w/o Shltr Transitional Res
# 119      YouthLink Shelter        YouthLink - 747 Warden Ave
#
#          SHELTER_ADDRESS SHELTER_CITY_x postal_code  latitudes  longitudes  \
# 0     1673 Kingston Road        Toronto     M1N 1S6  43.691569  -79.263923
# 1    1229 Ellesmere Road        Toronto     M1P 4V8  43.768282  -79.267447
# 2    1229 Ellesmere Road        Toronto     M1P 4V8  43.768282  -79.267447
# 3    1229 Ellesmere Road        Toronto     M1P 4V8  43.768282  -79.267447
# 4    1229 Ellesmere Road        Toronto     M1P 4V8  43.768282  -79.267447
# ..                   ...            ...         ...        ...         ...
# 115    348 Davenport Rd.        Toronto     M5R 1K6  43.675403  -79.401348
# 116    348 Davenport Rd.        Toronto     M5R 1K6  43.675403  -79.401348
# 117   6 Warrendale Court      Etobicoke     M9V 1P9  43.736293  -79.580427
# 118   6 Warrendale Court      Etobicoke     M9V 1P9  43.736293  -79.580427
# 119       747 Warden Ave        Toronto     M1L 4A8  43.717816  -79.282880
#
#      OCCUPANCY_mean  OCCUPANCY_median  OCCUPANCY_std  CAPACITY_mean  \
# 0         57.621918              59.0       2.564838      60.000000
# 1        173.078539             169.0      12.873355     168.522374
# 2        235.522036             172.0     145.775502     289.513346
# 3         15.720745              19.0       8.241798      25.821333
# 4          1.473469               2.0       0.786874       2.000000
# ..              ...               ...            ...            ...
# 115       37.446377              39.0       5.413500      38.104348
# 116       14.240469              15.0       1.911484      14.835777
# 117       32.605479              33.0       0.730360      33.000000
# 118       19.550685              20.0       0.723677      19.961644
# 119       22.394191              10.0      14.604210      23.595436
#
#      CAPACITY_median  CAPACITY_std
# 0               60.0      0.000000
# 1              160.0     17.514768
# 2              205.0    174.071090
# 3               36.0     13.605056
# 4                2.0      0.000000
# ..               ...           ...
# 115             40.0      5.443217
# 116             15.0      1.235270
# 117             33.0      0.000000
# 118             20.0      0.337196
# 119             10.0     15.145319
#
# [120 rows x 13 columns]

# %%
info_box_template = """
<dl>
<dt>Facility Name</dt><dd>{FACILITY_NAME}</dd>
<dt>Shelter Name</dt><dd>{SHELTER_NAME}</dd>
<dt>Address</dt><dd>{SHELTER_ADDRESS}</dd>
<dt>Median Occupancy</dt><dd>{OCCUPANCY_median}</dd>
<dt>Median Capacity</dt><dd>{CAPACITY_median}</dd>
</dl>
"""

homeless_info = [info_box_template.format(**row) for index, row in df_groupby2.iterrows()]
locations = df_groupby2[["latitudes", "longitudes"]]

# %%
gmaps.configure(api_key=google_api_key)

# %%
fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content=homeless_info)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
